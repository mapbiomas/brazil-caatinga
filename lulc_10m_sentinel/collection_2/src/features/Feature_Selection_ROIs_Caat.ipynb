# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### imports packages

# %%
import glob
import sys
import os
import copy
import json
import math
import time
import numpy as np
from pathlib import Path
from numpy import set_printoptions
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import svm
from matplotlib.ticker import NullFormatter
from sklearn import manifold, datasets
import plotly.express as px

# %%
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import RFECV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
# Create an array with the colors you want to use
colors = ["#006400","#00ff00","#B8AF4F","#FFD966","#E974ED","#EA9999","#0000FF"]
# Set your custom color palette
sns.set_palette(sns.color_palette(colors))

# %%
def make_df_withPlotPie(df_graf):
    dfCC = df_graf['class'].value_counts()
    dfCC = dfCC.reset_index()
    fig = px.pie(
            dfCC,
            values='count',
            names='class',
            # title= "Distribuição de amostras",
            color_discrete_sequence = colors
            )
    fig.update_layout(
        title=dict(text="Distribuição de amostras", font=dict(size=32), automargin=True, yref='paper'),
        width = 500
    )
    fig.update_traces(textinfo='value+percent')
    fig.show()

# %% [markdown]
# ### loading Data from drive

# %%
# Cloud authentication.
# from google.colab import auth
# from google.colab import drive

# auth.authenticate_user()
# drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# pathBase = '/content/drive/MyDrive/mapbiomas/featureSelection/shp_ROIs_S2_caat_red'  # shp_ROIs_S2_caat_red  # shp_ROIs_S2_caat
# pathFeaturesBase = '/content/drive/MyDrive/mapbiomas/featureSelection/featuresSelect'
# !ls /content/drive/MyDrive/mapbiomas/featureSelection/shp_ROIs_S2_caat_red
# Out:
# rois_grade_7411.csv  rois_grade_7561.csv    rois_grade_7615.csv  rois_grade_7712.csv
# rois_grade_7422.csv  rois_grade_7564.csv    rois_grade_7616.csv  rois_grade_771.csv
# rois_grade_7424.csv  rois_grade_757.csv     rois_grade_7617.csv  rois_grade_7721.csv
# rois_grade_7438.csv  rois_grade_7581.csv    rois_grade_7618.csv  rois_grade_772.csv
# rois_grade_7443.csv  rois_grade_7584.csv    rois_grade_7619.csv  rois_grade_773.csv
# rois_grade_745.csv   rois_grade_7591.csv    rois_grade_7622.csv  rois_grade_7741.csv
# rois_grade_746.csv   rois_grade_7592.csv    rois_grade_7625.csv  rois_grade_7746.csv
# rois_grade_751.csv   rois_grade_761111.csv  rois_grade_763.csv	 rois_grade_7754.csv
# rois_grade_752.csv   rois_grade_761112.csv  rois_grade_764.csv	 rois_grade_7761.csv
# rois_grade_753.csv   rois_grade_76116.csv   rois_grade_765.csv	 rois_grade_7764.csv
# rois_grade_7541.csv  rois_grade_7612.csv    rois_grade_766.csv
# rois_grade_7544.csv  rois_grade_7613.csv    rois_grade_7671.csv
# rois_grade_755.csv   rois_grade_7614.csv    rois_grade_7691.csv

# %%
pathBase = '/content/drive/MyDrive/mapbiomas/featureSelection/shp_ROIs_S2_caat_red'  # shp_ROIs_S2_caat_red  # shp_ROIs_S2_caat
pathFeaturesBase = '/home/superuser/Dados/mapbiomas/dev_collection_sentinel/src/features'
# !ls /home/superuser/Dados/mapbiomas/dev_collection_sentinel/src/features
# Out:
# Feature_Selection_ROIs_Caat.ipynb  rois_grade_7422_red_2016.csv

# %% [markdown]
# ### Load Tables and paramenter

# %%
# read many files CSVs
manyfile = False
filterYear = True
nyear = 2023
lstpathfiles = glob.glob(os.path.join(pathBase, "*.csv"))

# %% [markdown]
# ### Analises de Features Selection

# %%
class processin_features_byYears(object):
    columns_features = [
        "afvi_median","afvi_median_dry","afvi_median_wet","avi_median",
        "avi_median_dry","avi_median_wet","awei_median","awei_median_dry","awei_median_wet",
        "blue_median","blue_median_dry","blue_median_wet","blue_stdDev","brba_median",
        "brba_median_dry","brba_median_wet","brightness_median","brightness_median_dry","brightness_median_wet",
        "bsi_median","bsi_median_1","bsi_median_2","cvi_median",
        "cvi_median_dry","cvi_median_wet","dswi5_median","dswi5_median_dry","dswi5_median_wet",
        "evi_median","evi_median_dry","evi_median_wet","gcvi_median","gcvi_median_dry",
        "gcvi_median_wet","gemi_median","gemi_median_dry","gemi_median_wet","gli_median",
        "gli_median_dry","gli_median_wet","green_median","green_median_dry","green_median_texture",
        "green_median_wet","green_min","green_stdDev","gvmi_median","gvmi_median_dry",
        "gvmi_median_wet","iia_median","iia_median_dry","iia_median_wet","lswi_median",
        "lswi_median_dry","lswi_median_wet","mbi_median","mbi_median_dry","mbi_median_wet",
        "nddi_median","nddi_median_dry","nddi_median_wet","ndvi_median","ndvi_median_dry",
        "ndvi_median_wet","ndwi_median","ndwi_median_dry","ndwi_median_wet","nir_median",
        "nir_median_contrast","nir_median_dry","nir_median_dry_contrast","nir_median_wet","osavi_median",
        "osavi_median_dry","osavi_median_wet","ratio_median","ratio_median_dry","ratio_median_wet",
        "red_edge_1_median","red_edge_1_median_dry","red_edge_1_median_wet","red_edge_1_stdDev","red_edge_2_median",
        "red_edge_2_median_dry","red_edge_2_median_wet","red_edge_2_stdDev","red_edge_3_median","red_edge_3_median_dry",
        "red_edge_3_median_wet","red_edge_3_stdDev","red_edge_4_median","red_edge_4_median_dry","red_edge_4_median_wet",
        "red_edge_4_stdDev","red_median","red_median_contrast","red_median_dry","red_median_dry_contrast",
        "red_median_wet","red_min","red_stdDev","ri_median","ri_median_dry",
        "ri_median_wet","rvi_median","rvi_median_1","rvi_median_wet","shape_median",
        "shape_median_dry","shape_median_wet","swir1_median","swir1_median_dry","swir1_median_wet",
        "swir1_stdDev","swir2_median","swir2_median_dry","swir2_median_wet","swir2_stdDev",
        "ui_median","ui_median_dry","ui_median_wet","wetness_median","wetness_median_dry",
        "wetness_median_wet"
    ]
    classe = "class"

    def __init__(self, Ns_estimators, learning_rates, path_features):
        self.dfROIs = None
        self.dfCC = None
        self.yearAct = None
        self.lstClass = None
        self.lst_N_estimators = Ns_estimators
        self.lst_learning_rate = learning_rates
        self.path_features = path_features
        self.betterPmtrosSet = 0
        self.dictpmtGTB = {}
        count = 0
        for ne in self.lst_N_estimators:
            for lr in self.lst_learning_rate:
                self.dictpmtGTB[str(count)] = [ne, lr]
                print(f"# {count + 1} mudando n_estimators= {ne} & learning_rate= {lr}")
                count += 1

    def get_data(self, myDF, nYear):
        self.dfROIs = myDF
        self.yearAct = nYear
        self.lstClass = self.dfROIs[self.classe].unique().tolist()
        self.buildingPercentsofClass()

    def get_class_withSmallsize(self, dFrames, lstSearch):
        classeMin = []
        for cclass in lstSearch:
            nsize = dFrames[dFrames[self.classe] == cclass].shape[0]
            print(f" classe {cclass} == > size = {nsize}")
            if nsize < 4:
                classeMin.append(cclass)
        return classeMin

    def split_dataFrame(self, dFrame):
        # split data into inputs (X) and outputs (y)
        dFrame4 = dFrame[dFrame[self.classe] == 4]
        dFrameO = dFrame[dFrame[self.classe] != 4]
        # lstClasses  = [kk for kk in self.lstClass if kk != 4]
        addFeatext = False

        maximoROIs = self.dfCC[self.dfCC['class'] != 4]['count'].max()
        maximoROIs += 150
        newlstDF = []
        print("size dFrame4 ", dFrame4.shape, " and the next class maximum is ", maximoROIs)
        # sampled the N samples fro dataframe stratified
        tmpDF = dFrame4.sample(n= int(maximoROIs), random_state= np.random.seed(int(maximoROIs/ 2)), replace= True)  #
        concDF  = pd.concat([tmpDF, dFrameO], ignore_index=True) #
        print("temos {} filas ".format(concDF.shape))
        # concDF.head()
        lstCCg1 = [3,4,15,18]
        lstCCg2 = [12,21,22,33]
        print(" ====> analisando size of class smaller ")
        lstclassMinM = self.get_class_withSmallsize(dFrame, lstCCg2)

        if len(lstclassMinM)  > 0:
            for ccm in lstclassMinM:
                print(" --- will be remove class ---", ccm)
                lstCCg2.remove(ccm)
            addFeatext = True


        dFrameg1 = concDF[concDF[self.classe].isin(lstCCg1)]
        dFrameg2 = concDF[concDF[self.classe].isin(lstCCg2)]

        # print(f" adding {int(propCC * maximoROIs)} samples from class [{cclass}]")
        # X = dataFrame[self.columns_features[:]]
        # y = dataFrame[self.classe]
        X_traing1, X_testg1, y_traing1, y_testg1 = train_test_split(
                            dFrameg1[self.columns_features[:]], dFrameg1[self.classe],
                            train_size=0.05,
                            random_state=1,
                            shuffle=True,
                            stratify = dFrameg1[self.classe]
                        )
        print(f"colected Xtrain {X_traing1.shape[0]} | Xtest {X_testg1.shape[0]} | " +
                                f"ytrain {y_traing1.shape[0]} | ytest {y_testg1.shape[0]}")
        X_traing2, X_testg2, y_traing2, y_testg2 = train_test_split(
                            dFrameg2[self.columns_features[:]], dFrameg2[self.classe],
                            train_size=0.9,
                            random_state=1,
                            shuffle=True,
                            stratify = dFrameg2[self.classe]
                        )
        print(f"colected Xtrain {X_traing2.shape[0]} | Xtest {X_testg2.shape[0]} | " +
                                f"ytrain {y_traing2.shape[0]} | ytest {y_testg2.shape[0]}")


        self.X_train = pd.concat([X_traing1, X_traing2], ignore_index=True)
        self.X_test = pd.concat([X_testg1, X_testg2], ignore_index=True)
        self.y_train = pd.concat([y_traing1, y_traing2], ignore_index=True)
        self.y_test = pd.concat([y_testg1, y_testg2], ignore_index=True)

        print(f" ==== know we have {self.X_train.shape} to train ==== ")
        print(self.y_train.value_counts(normalize= True), self.y_train.value_counts())


    def buildingPercentsofClass(self):
        self.dfCC = self.dfROIs['class'].value_counts()
        self.dfCC = self.dfCC.reset_index()
        # get total number of classes
        total = np.sum(self.dfCC['count'].tolist())
        print(f"total = {total}")
        self.dfCC['percent'] = round((self.dfCC['count'] * 100)/ total, 2)
        self.dfCC['Years'] = np.ones(self.dfCC.shape[0]).astype(int) * self.yearAct
        # print(dfCC)
        print(f" == the CLASS of rois distribuided in {self.yearAct} are == \n ", self.dfCC)

    def processingMultiplesModels(self):
        # split the dataframe in stratify samples by class and balance class 4
        self.split_dataFrame(self.dfROIs)
        maximAcc = 0.0
        # get the models to evaluate
        models = self.get_models()
        # evaluate the models and store results
        results, names = list(), list()
        start = time.time()
        count = 1
        for name, model in models.items():
            print(f"#{count}/{len(models.items())} processing model {name}")
            scores = self.evaluate_model(model, self.X_train[self.columns_features[:]], self.y_train)
            results.append(scores)
            names.append(name)
            print('  >%s %.3f (%.3f)' % (name, np.mean(scores), np.std(scores)))
            if maximAcc < np.mean(scores):
                self.betterPmtrosSet = count - 1
                maximAcc = np.mean(scores)
            count += 1
        # plot model performance for comparison
        # plt.boxplot(results, labels=names, showmeans=True)
        # plt.show()
        end = time.time()
        tiempo = end - start
        if tiempo < 60:
            print(f"model trained in {tiempo} seconds")
        else:
            print(f"model trained in {tiempo/60} minutos")


    # get a list of models to evaluate
    def get_models(self):
        min_features_to_select = 7
        models = dict()

        # criando pipeline do modelos gradiente Boosting com varios paramentros
        cv = StratifiedKFold(3)
        for cc in range(len(self.dictpmtGTB.keys())):
            GTBmodel = GradientBoostingClassifier(
                            n_estimators= self.dictpmtGTB[str(cc)][0],
                            learning_rate= self.dictpmtGTB[str(cc)][1],
                            max_features= 7
                        )
            rfe = RFECV(
                    estimator=GTBmodel,
                    step=1,
                    cv=cv,
                    scoring="accuracy",
                    min_features_to_select=min_features_to_select,
                    n_jobs= -1,
                )

            models[str(cc)] = Pipeline(steps=[('s', rfe),('m', GTBmodel)])
        return models

    # evaluate a give model using cross-validation
    def evaluate_model(self, model, X, y):
        cv = StratifiedKFold(3)
        scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv,  error_score='raise') # n_jobs=-1,
        return scores


    def get_better_featuresSet(self, fixarNumbFeat, numbMin, regg, yyear):

        # Create a Path object
        path_name_file = self.path_features + f'/featuresSelectS2_{regg}_{yyear}.csv'
        file_path = Path(path_name_file)

        # Check if the file exists
        if file_path.exists():
            print(" ******* list of features selected was saved ********")

        else:
            self.split_dataFrame(self.dfROIs)

            GTBmodel = GradientBoostingClassifier(
                            n_estimators= self.dictpmtGTB[str(self.betterPmtrosSet)][0],
                            learning_rate= self.dictpmtGTB[str(self.betterPmtrosSet)][1],
                            max_features= 7,
                            random_state=42
                        )

            start = time.time()
            # Minimum number of features to consider
            min_features_to_select =  7
            cv = StratifiedKFold(3)
            rfecv = RFECV(
                estimator=GTBmodel,
                step=1,
                cv=cv,
                scoring="accuracy",
                min_features_to_select=min_features_to_select,
                n_jobs=-1,
            )
            rfecv.fit(self.X_train[self.columns_features], self.y_train)
            print(f"Optimal number of features: {rfecv.n_features_}")

            end = time.time()
            tiempo = end - start
            if tiempo < 60:
                print(f"model trained in {tiempo} seconds")
            else:
                print(f"model trained in {tiempo/60} minutos")

            ## valores ótimos aparecem com valor 1 no ranking
            lst_ranking = [(kk, cc) for cc, kk in enumerate(rfecv.ranking_) if kk < 2]
            print("quantos features otimos ", len(lst_ranking))
            numbNotOti = numbMin
            if fixarNumbFeat and numbMin > len(lst_ranking):
                numbNotOti = numbMin - len(lst_ranking)
                print(f"Addicionando << {numbNotOti} >> features a mais não ótimas ")
                lst_ranking = [(kk, cc) for cc, kk in enumerate(rfecv.ranking_) if kk < numbNotOti]
            print("quantos features otimos ", len(lst_ranking))

            lstFeatSelect = []
            ccount = 1
            for kk, cc in lst_ranking:
                print(f"# {ccount} ranking {kk} | pos {cc} >> feature >> {self.columns_features[cc]}")
                lstFeatSelect.append(self.columns_features[cc])
                ccount += 1

            dict_result= {
                'ranking': lst_ranking,
                'features': lstFeatSelect
            }
            dfresult = pd.DataFrame.from_dict(dict_result)
            dfresult.to_csv(path_name_file, index= False)

            print("tabela salva em pasta do drive")

# %%
lstYear = list(range(2023, 2015, -1))
print(" year ", lstYear);
# sys.exit()
# fixar o número de variaveis
fixarNFeat = True
# número máximo de variaveis para o modelo das 144
numMin = 70
yyear = 2023
lstEstimadors = [20, 30, 40, 50, 60]
lstLearnRate = [0.001, 0.005, 0.01, 0.1]
melhorModelo = 0
dictModel = {}
# Out:
#  year  [2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016]

# %%
# instanciar classe de processamento dos Features
procFeatures_byYears = processin_features_byYears(lstEstimadors, lstLearnRate, pathFeaturesBase)
# Out:
# # 1 mudando n_estimators= 20 & learning_rate= 0.001
# # 2 mudando n_estimators= 20 & learning_rate= 0.005
# # 3 mudando n_estimators= 20 & learning_rate= 0.01
# # 4 mudando n_estimators= 20 & learning_rate= 0.1
# # 5 mudando n_estimators= 30 & learning_rate= 0.001
# # 6 mudando n_estimators= 30 & learning_rate= 0.005
# # 7 mudando n_estimators= 30 & learning_rate= 0.01
# # 8 mudando n_estimators= 30 & learning_rate= 0.1
# # 9 mudando n_estimators= 40 & learning_rate= 0.001
# # 10 mudando n_estimators= 40 & learning_rate= 0.005
# # 11 mudando n_estimators= 40 & learning_rate= 0.01
# # 12 mudando n_estimators= 40 & learning_rate= 0.1
# # 13 mudando n_estimators= 50 & learning_rate= 0.001
# # 14 mudando n_estimators= 50 & learning_rate= 0.005
# # 15 mudando n_estimators= 50 & learning_rate= 0.01
# # 16 mudando n_estimators= 50 & learning_rate= 0.1
# # 17 mudando n_estimators= 60 & learning_rate= 0.001
# # 18 mudando n_estimators= 60 & learning_rate= 0.005
# # 19 mudando n_estimators= 60 & learning_rate= 0.01
# # 20 mudando n_estimators= 60 & learning_rate= 0.1

# %%
dictModelsS = {}
pathModelJson = '/content/drive/MyDrive/mapbiomas/featureSelection/dictBetterModelpmtSetv2.json'
try:
    with open(pathModelJson, 'r') as fh:
        dictModelsS = json.load(fh)
    print("loaded dictModel => ", dictModelsS)
    print(f"with {len(dictModelsS.keys())} register")
except:
    print("generate dictModel => {}")

count = 0
for ne in lstEstimadors:
    for lr in lstLearnRate:
        dictModel[str(count)] = [ne, lr]
        # print(f"# {count + 1} mudando n_estimators= {ne} & learning_rate= {lr}")
        count += 1
# Out:
# loaded dictModel =>  {'7581': {'better_pmtSet': 15, 'n_estimators': 50, 'learning_rate': 0.1}, '7691': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1}, '7625': {'better_pmtSet': 15, 'n_estimators': 50, 'learning_rate': 0.1}, '7754': {'better_pmtSet': 11, 'n_estimators': 40, 'learning_rate': 0.1}, '751': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1}, '7584': {'better_pmtSet': 15, 'n_estimators': 50, 'learning_rate': 0.1}, '7614': {'better_pmtSet': 11, 'n_estimators': 40, 'learning_rate': 0.1}, '7616': {'better_pmtSet': 11, 'n_estimators': 40, 'learning_rate': 0.1}, '752': {'better_pmtSet': 15, 'n_estimators': 50, 'learning_rate': 0.1}, '745': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1}, '7424': {'better_pmtSet': 3, 'n_estimators': 20, 'learning_rate': 0.1}, '773': {'better_pmtSet': 15, 'n_estimators': 50, 'learning_rate': 0.1}, '7612': {'better_pmtSet': 15, 'n_estimators': 50, 'learning_rate': 0.1}, '7613': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1}, '7618': {'better_pmtSet': 3, 'n_estimators': 20, 'learning_rate': 0.1}, '755': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1}, '7617': {'better_pmtSet': 11, 'n_estimators': 40, 'learning_rate': 0.1}, '7561': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1}, '761112': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1}, '7564': {'better_pmtSet': 15, 'n_estimators': 50, 'learning_rate': 0.1}, '7422': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1}, '7761': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1}, '761111': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1}, '7671': {'better_pmtSet': 15, 'n_estimators': 50, 'learning_rate': 0.1}, '7741': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1}, '7615': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1}, '76116': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1}, '7411': {'better_pmtSet': 15, 'n_estimators': 50, 'learning_rate': 0.1}, '771': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1}, '7712': {'better_pmtSet': 11, 'n_estimators': 40, 'learning_rate': 0.1}, '757': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1}, '753': {'better_pmtSet': 7, 'n_estimators': 30, 'learning_rate': 0.1}, '7746': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1}}
# with 33 register

# %%
dictModelsS
# Out:
# {'7581': {'better_pmtSet': 15, 'n_estimators': 50, 'learning_rate': 0.1},
#  '7691': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1},
#  '7625': {'better_pmtSet': 15, 'n_estimators': 50, 'learning_rate': 0.1},
#  '7754': {'better_pmtSet': 11, 'n_estimators': 40, 'learning_rate': 0.1},
#  '751': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1},
#  '7584': {'better_pmtSet': 15, 'n_estimators': 50, 'learning_rate': 0.1},
#  '7614': {'better_pmtSet': 11, 'n_estimators': 40, 'learning_rate': 0.1},
#  '7616': {'better_pmtSet': 11, 'n_estimators': 40, 'learning_rate': 0.1},
#  '752': {'better_pmtSet': 15, 'n_estimators': 50, 'learning_rate': 0.1},
#  '745': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1},
#  '7424': {'better_pmtSet': 3, 'n_estimators': 20, 'learning_rate': 0.1},
#  '773': {'better_pmtSet': 15, 'n_estimators': 50, 'learning_rate': 0.1},
#  '7612': {'better_pmtSet': 15, 'n_estimators': 50, 'learning_rate': 0.1},
#  '7613': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1},
#  '7618': {'better_pmtSet': 3, 'n_estimators': 20, 'learning_rate': 0.1},
#  '755': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1},
#  '7617': {'better_pmtSet': 11, 'n_estimators': 40, 'learning_rate': 0.1},
#  '7561': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1},
#  '761112': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1},
#  '7564': {'better_pmtSet': 15, 'n_estimators': 50, 'learning_rate': 0.1},
#  '7422': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1},
#  '7761': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1},
#  '761111': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1},
#  '7671': {'better_pmtSet': 15, 'n_estimators': 50, 'learning_rate': 0.1},
#  '7741': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1},
#  '7615': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1},
#  '76116': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1},
#  '7411': {'better_pmtSet': 15, 'n_estimators': 50, 'learning_rate': 0.1},
#  '771': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1},
#  '7712': {'better_pmtSet': 11, 'n_estimators': 40, 'learning_rate': 0.1},
#  '757': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1},
#  '753': {'better_pmtSet': 7, 'n_estimators': 30, 'learning_rate': 0.1},
#  '7746': {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1}}

# %%
for cc, npath in enumerate(lstpathfiles[:]):
    df_bacia = {}
    print("Loading ==> " + npath)
    nbacia = npath.split("_")[-1].replace('.csv', '')
    dftable = pd.read_csv(npath)
    dftable = dftable.drop(['system:index','.geo'], axis=1)
    print("  columns = ", dftable.columns)
    print(f" == Know how many rois have in the table == \n ",
                                dftable.year.value_counts())

    dftableYY = dftable[dftable['year'] == yyear]
    procFeatures_byYears.get_data(dftableYY, yyear)
    lstKeysBa = [kk for kk in dictModelsS.keys()]
    print(f" basin activate {nbacia} and the other Regions processadas \n ==> ", lstKeysBa)

    if nbacia not in lstKeysBa:
        procFeatures_byYears.processingMultiplesModels()
        melhorModelo = procFeatures_byYears.betterPmtrosSet
        dictModelsS[nbacia] = {
            'better_pmtSet': melhorModelo,
            'n_estimators': dictModel[str(melhorModelo)][0],
            'learning_rate': dictModel[str(melhorModelo)][1]
        }
        # Convert and write JSON object to file
        with open(pathModelJson, "w") as outfile:
            json.dump(dictModelsS, outfile)

    else:
        df_bacia = dictModelsS[nbacia]
        print("selecionou model feito ", df_bacia)
        procFeatures_byYears.betterPmtrosSet = df_bacia['better_pmtSet']
    # break
    for nyear in lstYear:
        dftableYY = dftable[dftable['year'] == nyear]
        procFeatures_byYears.get_data(dftableYY, nyear)
        procFeatures_byYears.get_better_featuresSet(fixarNFeat, numMin, nbacia, nyear)
# Out:
# Streaming output truncated to the last 5000 lines.
#  ******* list of features selected was saved ********
# total = 94044
#  == the CLASS of rois distribuided in 2020 are ==
#      class  count  percent  Years
# 0      4  48452    51.52   2020
# 1      3  27064    28.78   2020
# 2     15  14952    15.90   2020
# 3     18   1552     1.65   2020
# 4     25   1052     1.12   2020
# 5     33    588     0.63   2020
# 6     12    384     0.41   2020
#  ******* list of features selected was saved ********
# total = 117225
#  == the CLASS of rois distribuided in 2019 are ==
#      class  count  percent  Years
# 0      4  61760    52.69   2019
# 1      3  33715    28.76   2019
# 2     15  17330    14.78   2019
# 3     18   1870     1.60   2019
# 4     25   1330     1.13   2019
# 5     33    735     0.63   2019
# 6     12    485     0.41   2019
#  ******* list of features selected was saved ********
# total = 140724
#  == the CLASS of rois distribuided in 2018 are ==
#      class  count  percent  Years
# 0      4  74868    53.20   2018
# 1      3  40176    28.55   2018
# 2     15  20652    14.68   2018
# 3     18   2268     1.61   2018
# 4     25   1458     1.04   2018
# 5     33    756     0.54   2018
# 6     12    546     0.39   2018
#  ******* list of features selected was saved ********
# total = 165214
#  == the CLASS of rois distribuided in 2017 are ==
#      class  count  percent  Years
# 0      4  89845    54.38   2017
# 1      3  48230    29.19   2017
# 2     15  21322    12.91   2017
# 3     18   2660     1.61   2017
# 4     25   1554     0.94   2017
# 5     33    910     0.55   2017
# 6     12    693     0.42   2017
#  ******* list of features selected was saved ********
# total = 187176
#  == the CLASS of rois distribuided in 2016 are ==
#      class   count  percent  Years
# 0      4  104152    55.64   2016
# 1      3   52336    27.96   2016
# 2     15   24032    12.84   2016
# 3     18    3176     1.70   2016
# 4     25    1944     1.04   2016
# 5     33     912     0.49   2016
# 6     12     624     0.33   2016
#  ******* list of features selected was saved ********
# Loading ==> /content/drive/MyDrive/mapbiomas/featureSelection/shp_ROIs_S2_caat_red/rois_grade_771.csv
#   columns =  Index(['GRID_ID', 'afvi_median', 'afvi_median_dry', 'afvi_median_wet',
#        'avi_median', 'avi_median_dry', 'avi_median_wet', 'awei_median',
#        'awei_median_dry', 'awei_median_wet',
#        ...
#        'swir2_median_dry', 'swir2_median_wet', 'swir2_stdDev', 'ui_median',
#        'ui_median_dry', 'ui_median_wet', 'wetness_median',
#        'wetness_median_dry', 'wetness_median_wet', 'year'],
#       dtype='object', length=127)
#  == Know how many rois have in the table ==
#   year
# 2016    176344
# 2017    156240
# 2018    132588
# 2019    111305
# 2020     89560
# 2021     66297
# 2022     43572
# 2023     21810
# Name: count, dtype: int64
# total = 21810
#  == the CLASS of rois distribuided in 2023 are ==
#      class  count  percent  Years
# 0     15  15004    68.79   2023
# 1     18   2692    12.34   2023
# 2      3   2238    10.26   2023
# 3      4   1129     5.18   2023
# 4     25    360     1.65   2023
# 5     33    326     1.49   2023
# 6     12     61     0.28   2023
#  basin activate 771 and the other Regions processadas
#  ==>  ['7581', '7691', '7625', '7754', '751', '7584', '7614', '7616', '752', '745', '7424', '773', '7612', '7613', '7618', '755', '7617', '7561', '761112', '7564', '7422', '7761', '761111', '7671', '7741', '7615', '76116', '7411', '771', '7712', '757', '753', '7746']
# selecionou model feito  {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1}
# total = 21810
#  == the CLASS of rois distribuided in 2023 are ==
#      class  count  percent  Years
# 0     15  15004    68.79   2023
# 1     18   2692    12.34   2023
# 2      3   2238    10.26   2023
# 3      4   1129     5.18   2023
# 4     25    360     1.65   2023
# 5     33    326     1.49   2023
# 6     12     61     0.28   2023
#  ******* list of features selected was saved ********
# total = 43572
#  == the CLASS of rois distribuided in 2022 are ==
#      class  count  percent  Years
# 0     15  29960    68.76   2022
# 1     18   5384    12.36   2022
# 2      3   4406    10.11   2022
# 3      4   2340     5.37   2022
# 4     25    734     1.68   2022
# 5     33    634     1.46   2022
# 6     12    114     0.26   2022
#  ******* list of features selected was saved ********
# total = 66297
#  == the CLASS of rois distribuided in 2021 are ==
#      class  count  percent  Years
# 0     15  45567    68.73   2021
# 1     18   8427    12.71   2021
# 2      3   6603     9.96   2021
# 3      4   3495     5.27   2021
# 4     25   1077     1.62   2021
# 5     33    942     1.42   2021
# 6     12    186     0.28   2021
#  ******* list of features selected was saved ********
# total = 89560
#  == the CLASS of rois distribuided in 2020 are ==
#      class  count  percent  Years
# 0     15  61236    68.37   2020
# 1     18  11856    13.24   2020
# 2      3   8640     9.65   2020
# 3      4   4904     5.48   2020
# 4     25   1444     1.61   2020
# 5     33   1252     1.40   2020
# 6     12    228     0.25   2020
#  ******* list of features selected was saved ********
# total = 111305
#  == the CLASS of rois distribuided in 2019 are ==
#      class  count  percent  Years
# 0     15  76590    68.81   2019
# 1     18  14515    13.04   2019
# 2      3  10990     9.87   2019
# 3      4   5765     5.18   2019
# 4     25   1695     1.52   2019
# 5     33   1585     1.42   2019
# 6     12    165     0.15   2019
#  ******* list of features selected was saved ********
# total = 132588
#  == the CLASS of rois distribuided in 2018 are ==
#      class  count  percent  Years
# 0     15  91128    68.73   2018
# 1     18  17352    13.09   2018
# 2      3  12798     9.65   2018
# 3      4   7170     5.41   2018
# 4     25   1998     1.51   2018
# 5     33   1872     1.41   2018
# 6     12    270     0.20   2018
#  ******* list of features selected was saved ********
# total = 156240
#  == the CLASS of rois distribuided in 2017 are ==
#      class   count  percent  Years
# 0     15  106862    68.40   2017
# 1     18   20664    13.23   2017
# 2      3   15106     9.67   2017
# 3      4    8568     5.48   2017
# 4     25    2359     1.51   2017
# 5     33    2142     1.37   2017
# 6     12     539     0.34   2017
#  ******* list of features selected was saved ********
# total = 176344
#  == the CLASS of rois distribuided in 2016 are ==
#      class   count  percent  Years
# 0     15  123040    69.77   2016
# 1     18   20904    11.85   2016
# 2      3   16760     9.50   2016
# 3      4    9824     5.57   2016
# 4     25    2648     1.50   2016
# 5     33    2480     1.41   2016
# 6     12     688     0.39   2016
#  ******* list of features selected was saved ********
# Loading ==> /content/drive/MyDrive/mapbiomas/featureSelection/shp_ROIs_S2_caat_red/rois_grade_7712.csv
#   columns =  Index(['GRID_ID', 'afvi_median', 'afvi_median_dry', 'afvi_median_wet',
#        'avi_median', 'avi_median_dry', 'avi_median_wet', 'awei_median',
#        'awei_median_dry', 'awei_median_wet',
#        ...
#        'swir2_median_dry', 'swir2_median_wet', 'swir2_stdDev', 'ui_median',
#        'ui_median_dry', 'ui_median_wet', 'wetness_median',
#        'wetness_median_dry', 'wetness_median_wet', 'year'],
#       dtype='object', length=127)
#  == Know how many rois have in the table ==
#   year
# 2016    165912
# 2017    145292
# 2018    123168
# 2019    103705
# 2020     83276
# 2021     61446
# 2022     40778
# 2023     20385
# Name: count, dtype: int64
# total = 20385
#  == the CLASS of rois distribuided in 2023 are ==
#      class  count  percent  Years
# 0     15  11380    55.83   2023
# 1      4   6182    30.33   2023
# 2     18   2602    12.76   2023
# 3     25    107     0.52   2023
# 4      3     76     0.37   2023
# 5     33     37     0.18   2023
# 6     12      1     0.00   2023
#  basin activate 7712 and the other Regions processadas
#  ==>  ['7581', '7691', '7625', '7754', '751', '7584', '7614', '7616', '752', '745', '7424', '773', '7612', '7613', '7618', '755', '7617', '7561', '761112', '7564', '7422', '7761', '761111', '7671', '7741', '7615', '76116', '7411', '771', '7712', '757', '753', '7746']
# selecionou model feito  {'better_pmtSet': 11, 'n_estimators': 40, 'learning_rate': 0.1}
# total = 20385
#  == the CLASS of rois distribuided in 2023 are ==
#      class  count  percent  Years
# 0     15  11380    55.83   2023
# 1      4   6182    30.33   2023
# 2     18   2602    12.76   2023
# 3     25    107     0.52   2023
# 4      3     76     0.37   2023
# 5     33     37     0.18   2023
# 6     12      1     0.00   2023
#  ******* list of features selected was saved ********
# total = 40778
#  == the CLASS of rois distribuided in 2022 are ==
#      class  count  percent  Years
# 0     15  22814    55.95   2022
# 1      4  12262    30.07   2022
# 2     18   5204    12.76   2022
# 3     25    240     0.59   2022
# 4      3    170     0.42   2022
# 5     33     86     0.21   2022
# 6     12      2     0.00   2022
#  ******* list of features selected was saved ********
# total = 61446
#  == the CLASS of rois distribuided in 2021 are ==
#      class  count  percent  Years
# 0     15  33756    54.94   2021
# 1      4  18975    30.88   2021
# 2     18   7932    12.91   2021
# 3     25    348     0.57   2021
# 4      3    306     0.50   2021
# 5     33    111     0.18   2021
# 6     12     18     0.03   2021
#  ******* list of features selected was saved ********
# total = 83276
#  == the CLASS of rois distribuided in 2020 are ==
#      class  count  percent  Years
# 0     15  45736    54.92   2020
# 1      4  25640    30.79   2020
# 2     18  10628    12.76   2020
# 3      3    648     0.78   2020
# 4     25    436     0.52   2020
# 5     33    160     0.19   2020
# 6     12     28     0.03   2020
#  ******* list of features selected was saved ********
# total = 103705
#  == the CLASS of rois distribuided in 2019 are ==
#      class  count  percent  Years
# 0     15  57260    55.21   2019
# 1      4  32650    31.48   2019
# 2     18  12570    12.12   2019
# 3     25    530     0.51   2019
# 4      3    510     0.49   2019
# 5     33    180     0.17   2019
# 6     12      5     0.00   2019
#  ******* list of features selected was saved ********
# total = 123168
#  == the CLASS of rois distribuided in 2018 are ==
#      class  count  percent  Years
# 0     15  67746    55.00   2018
# 1      4  39690    32.22   2018
# 2     18  14448    11.73   2018
# 3     25    756     0.61   2018
# 4      3    270     0.22   2018
# 5     33    240     0.19   2018
# 6     12     18     0.01   2018
#  ******* list of features selected was saved ********
# total = 145292
#  == the CLASS of rois distribuided in 2017 are ==
#      class  count  percent  Years
# 0     15  79982    55.05   2017
# 1      4  47159    32.46   2017
# 2     18  16723    11.51   2017
# 3     25    672     0.46   2017
# 4      3    406     0.28   2017
# 5     33    294     0.20   2017
# 6     12     56     0.04   2017
#  ******* list of features selected was saved ********
# total = 165912
#  == the CLASS of rois distribuided in 2016 are ==
#      class  count  percent  Years
# 0     15  92144    55.54   2016
# 1      4  55088    33.20   2016
# 2     18  17008    10.25   2016
# 3     25    832     0.50   2016
# 4      3    472     0.28   2016
# 5     33    272     0.16   2016
# 6     12     96     0.06   2016
#  ******* list of features selected was saved ********
# Loading ==> /content/drive/MyDrive/mapbiomas/featureSelection/shp_ROIs_S2_caat_red/rois_grade_757.csv
#   columns =  Index(['GRID_ID', 'afvi_median', 'afvi_median_dry', 'afvi_median_wet',
#        'avi_median', 'avi_median_dry', 'avi_median_wet', 'awei_median',
#        'awei_median_dry', 'awei_median_wet',
#        ...
#        'swir2_median_dry', 'swir2_median_wet', 'swir2_stdDev', 'ui_median',
#        'ui_median_dry', 'ui_median_wet', 'wetness_median',
#        'wetness_median_dry', 'wetness_median_wet', 'year'],
#       dtype='object', length=127)
#  == Know how many rois have in the table ==
#   year
# 2016    204320
# 2017    179550
# 2018    153708
# 2019    127930
# 2020    102048
# 2021     75447
# 2022     49394
# 2023     24676
# Name: count, dtype: int64
# total = 24676
#  == the CLASS of rois distribuided in 2023 are ==
#      class  count  percent  Years
# 0     15  10400    42.15   2023
# 1      4   6598    26.74   2023
# 2     18   5676    23.00   2023
# 3      3    923     3.74   2023
# 4     33    490     1.99   2023
# 5     25    490     1.99   2023
# 6     12     99     0.40   2023
#  basin activate 757 and the other Regions processadas
#  ==>  ['7581', '7691', '7625', '7754', '751', '7584', '7614', '7616', '752', '745', '7424', '773', '7612', '7613', '7618', '755', '7617', '7561', '761112', '7564', '7422', '7761', '761111', '7671', '7741', '7615', '76116', '7411', '771', '7712', '757', '753', '7746']
# selecionou model feito  {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1}
# total = 24676
#  == the CLASS of rois distribuided in 2023 are ==
#      class  count  percent  Years
# 0     15  10400    42.15   2023
# 1      4   6598    26.74   2023
# 2     18   5676    23.00   2023
# 3      3    923     3.74   2023
# 4     33    490     1.99   2023
# 5     25    490     1.99   2023
# 6     12     99     0.40   2023
#  ******* list of features selected was saved ********
# total = 49394
#  == the CLASS of rois distribuided in 2022 are ==
#      class  count  percent  Years
# 0     15  20820    42.15   2022
# 1      4  13028    26.38   2022
# 2     18  11344    22.97   2022
# 3      3   1844     3.73   2022
# 4     25   1074     2.17   2022
# 5     33    992     2.01   2022
# 6     12    292     0.59   2022
#  ******* list of features selected was saved ********
# total = 75447
#  == the CLASS of rois distribuided in 2021 are ==
#      class  count  percent  Years
# 0     15  32187    42.66   2021
# 1      4  19545    25.91   2021
# 2     18  17472    23.16   2021
# 3      3   2868     3.80   2021
# 4     33   1563     2.07   2021
# 5     25   1404     1.86   2021
# 6     12    408     0.54   2021
#  ******* list of features selected was saved ********
# total = 102048
#  == the CLASS of rois distribuided in 2020 are ==
#      class  count  percent  Years
# 0     15  43440    42.57   2020
# 1      4  26688    26.15   2020
# 2     18  23392    22.92   2020
# 3      3   3904     3.83   2020
# 4     33   2080     2.04   2020
# 5     25   1968     1.93   2020
# 6     12    576     0.56   2020
#  ******* list of features selected was saved ********
# total = 127930
#  == the CLASS of rois distribuided in 2019 are ==
#      class  count  percent  Years
# 0     15  53960    42.18   2019
# 1      4  34830    27.23   2019
# 2     18  28925    22.61   2019
# 3      3   4550     3.56   2019
# 4     33   2560     2.00   2019
# 5     25   2355     1.84   2019
# 6     12    750     0.59   2019
#  ******* list of features selected was saved ********
# total = 153708
#  == the CLASS of rois distribuided in 2018 are ==
#      class  count  percent  Years
# 0     15  65466    42.59   2018
# 1      4  42468    27.63   2018
# 2     18  33654    21.89   2018
# 3      3   5358     3.49   2018
# 4     33   3162     2.06   2018
# 5     25   2736     1.78   2018
# 6     12    864     0.56   2018
#  ******* list of features selected was saved ********
# total = 179550
#  == the CLASS of rois distribuided in 2017 are ==
#      class  count  percent  Years
# 0     15  79142    44.08   2017
# 1      4  49063    27.33   2017
# 2     18  37744    21.02   2017
# 3      3   6153     3.43   2017
# 4     33   3360     1.87   2017
# 5     25   3010     1.68   2017
# 6     12   1078     0.60   2017
#  ******* list of features selected was saved ********
# total = 204320
#  == the CLASS of rois distribuided in 2016 are ==
#      class  count  percent  Years
# 0     15  89296    43.70   2016
# 1      4  57352    28.07   2016
# 2     18  42024    20.57   2016
# 3      3   6984     3.42   2016
# 4     33   3896     1.91   2016
# 5     25   3336     1.63   2016
# 6     12   1432     0.70   2016
#  ******* list of features selected was saved ********
# Loading ==> /content/drive/MyDrive/mapbiomas/featureSelection/shp_ROIs_S2_caat_red/rois_grade_753.csv
#   columns =  Index(['GRID_ID', 'afvi_median', 'afvi_median_dry', 'afvi_median_wet',
#        'avi_median', 'avi_median_dry', 'avi_median_wet', 'awei_median',
#        'awei_median_dry', 'awei_median_wet',
#        ...
#        'swir2_median_dry', 'swir2_median_wet', 'swir2_stdDev', 'ui_median',
#        'ui_median_dry', 'ui_median_wet', 'wetness_median',
#        'wetness_median_dry', 'wetness_median_wet', 'year'],
#       dtype='object', length=127)
#  == Know how many rois have in the table ==
#   year
# 2016    202064
# 2017    184702
# 2018    158034
# 2019    131415
# 2020    105844
# 2021     79101
# 2022     52008
# 2023     26435
# Name: count, dtype: int64
# total = 26435
#  == the CLASS of rois distribuided in 2023 are ==
#      class  count  percent  Years
# 0      4  13235    50.07   2023
# 1      3   4554    17.23   2023
# 2     15   3958    14.97   2023
# 3     18   3315    12.54   2023
# 4     25    754     2.85   2023
# 5     33    604     2.28   2023
# 6     12     15     0.06   2023
#  basin activate 753 and the other Regions processadas
#  ==>  ['7581', '7691', '7625', '7754', '751', '7584', '7614', '7616', '752', '745', '7424', '773', '7612', '7613', '7618', '755', '7617', '7561', '761112', '7564', '7422', '7761', '761111', '7671', '7741', '7615', '76116', '7411', '771', '7712', '757', '753', '7746']
# selecionou model feito  {'better_pmtSet': 7, 'n_estimators': 30, 'learning_rate': 0.1}
# total = 26435
#  == the CLASS of rois distribuided in 2023 are ==
#      class  count  percent  Years
# 0      4  13235    50.07   2023
# 1      3   4554    17.23   2023
# 2     15   3958    14.97   2023
# 3     18   3315    12.54   2023
# 4     25    754     2.85   2023
# 5     33    604     2.28   2023
# 6     12     15     0.06   2023
#  ******* list of features selected was saved ********
# total = 52008
#  == the CLASS of rois distribuided in 2022 are ==
#      class  count  percent  Years
# 0      4  26932    51.78   2022
# 1     15   8028    15.44   2022
# 2      3   7762    14.92   2022
# 3     18   6618    12.72   2022
# 4     25   1476     2.84   2022
# 5     33   1144     2.20   2022
# 6     12     48     0.09   2022
#  ******* list of features selected was saved ********
# total = 79101
#  == the CLASS of rois distribuided in 2021 are ==
#      class  count  percent  Years
# 0      4  39738    50.24   2021
# 1      3  13269    16.77   2021
# 2     15  12258    15.50   2021
# 3     18   9783    12.37   2021
# 4     25   2253     2.85   2021
# 5     33   1731     2.19   2021
# 6     12     69     0.09   2021
#  ******* list of features selected was saved ********
# total = 105844
#  == the CLASS of rois distribuided in 2020 are ==
#      class  count  percent  Years
# 0      4  54256    51.26   2020
# 1      3  17440    16.48   2020
# 2     15  15456    14.60   2020
# 3     18  13208    12.48   2020
# 4     25   3056     2.89   2020
# 5     33   2336     2.21   2020
# 6     12     92     0.09   2020
#  ******* list of features selected was saved ********
# total = 131415
#  == the CLASS of rois distribuided in 2019 are ==
#      class  count  percent  Years
# 0      4  68505    52.13   2019
# 1      3  21860    16.63   2019
# 2     15  18495    14.07   2019
# 3     18  15785    12.01   2019
# 4     25   3830     2.91   2019
# 5     33   2830     2.15   2019
# 6     12    110     0.08   2019
#  ******* list of features selected was saved ********
# total = 158034
#  == the CLASS of rois distribuided in 2018 are ==
#      class  count  percent  Years
# 0      4  82128    51.97   2018
# 1      3  27378    17.32   2018
# 2     15  22098    13.98   2018
# 3     18  18948    11.99   2018
# 4     25   4302     2.72   2018
# 5     33   3006     1.90   2018
# 6     12    174     0.11   2018
#  ******* list of features selected was saved ********
# total = 184702
#  == the CLASS of rois distribuided in 2017 are ==
#      class  count  percent  Years
# 0      4  95837    51.89   2017
# 1      3  32438    17.56   2017
# 2     15  26446    14.32   2017
# 3     18  22064    11.95   2017
# 4     25   4613     2.50   2017
# 5     33   3052     1.65   2017
# 6     12    252     0.14   2017
#  ******* list of features selected was saved ********
# total = 202064
#  == the CLASS of rois distribuided in 2016 are ==
#      class   count  percent  Years
# 0      4  105208    52.07   2016
# 1      3   34456    17.05   2016
# 2     15   29320    14.51   2016
# 3     18   24560    12.15   2016
# 4     25    5200     2.57   2016
# 5     33    3104     1.54   2016
# 6     12     216     0.11   2016
#  ******* list of features selected was saved ********
# Loading ==> /content/drive/MyDrive/mapbiomas/featureSelection/shp_ROIs_S2_caat_red/rois_grade_7746.csv
#   columns =  Index(['GRID_ID', 'afvi_median', 'afvi_median_dry', 'afvi_median_wet',
#        'avi_median', 'avi_median_dry', 'avi_median_wet', 'awei_median',
#        'awei_median_dry', 'awei_median_wet',
#        ...
#        'swir2_median_dry', 'swir2_median_wet', 'swir2_stdDev', 'ui_median',
#        'ui_median_dry', 'ui_median_wet', 'wetness_median',
#        'wetness_median_dry', 'wetness_median_wet', 'year'],
#       dtype='object', length=127)
#  == Know how many rois have in the table ==
#   year
# 2017    255220
# 2016    233288
# 2018    215778
# 2019    179615
# 2020    143028
# 2021    106200
# 2022     70538
# 2023     35134
# Name: count, dtype: int64
# total = 35134
#  == the CLASS of rois distribuided in 2023 are ==
#      class  count  percent  Years
# 0     15  13394    38.12   2023
# 1      4  12208    34.75   2023
# 2      3   5761    16.40   2023
# 3     18   3039     8.65   2023
# 4     12    495     1.41   2023
# 5     25    193     0.55   2023
# 6     33     44     0.13   2023
#  basin activate 7746 and the other Regions processadas
#  ==>  ['7581', '7691', '7625', '7754', '751', '7584', '7614', '7616', '752', '745', '7424', '773', '7612', '7613', '7618', '755', '7617', '7561', '761112', '7564', '7422', '7761', '761111', '7671', '7741', '7615', '76116', '7411', '771', '7712', '757', '753', '7746']
# selecionou model feito  {'better_pmtSet': 19, 'n_estimators': 60, 'learning_rate': 0.1}
# total = 35134
#  == the CLASS of rois distribuided in 2023 are ==
#      class  count  percent  Years
# 0     15  13394    38.12   2023
# 1      4  12208    34.75   2023
# 2      3   5761    16.40   2023
# 3     18   3039     8.65   2023
# 4     12    495     1.41   2023
# 5     25    193     0.55   2023
# 6     33     44     0.13   2023
#  ******* list of features selected was saved ********
# total = 70538
#  == the CLASS of rois distribuided in 2022 are ==
#      class  count  percent  Years
# 0     15  26728    37.89   2022
# 1      4  24208    34.32   2022
# 2      3  11834    16.78   2022
# 3     18   6078     8.62   2022
# 4     12   1162     1.65   2022
# 5     25    430     0.61   2022
# 6     33     98     0.14   2022
#  ******* list of features selected was saved ********
# total = 106200
#  == the CLASS of rois distribuided in 2021 are ==
#      class  count  percent  Years
# 0     15  40887    38.50   2021
# 1      4  36591    34.45   2021
# 2      3  17289    16.28   2021
# 3     18   8865     8.35   2021
# 4     12   1854     1.75   2021
# 5     25    588     0.55   2021
# 6     33    126     0.12   2021
#  ******* list of features selected was saved ********
# total = 143028
#  == the CLASS of rois distribuided in 2020 are ==
#      class  count  percent  Years
# 0     15  55044    38.48   2020
# 1      4  50184    35.09   2020
# 2      3  23032    16.10   2020
# 3     18  11336     7.93   2020
# 4     12   2460     1.72   2020
# 5     25    764     0.53   2020
# 6     33    208     0.15   2020
#  ******* list of features selected was saved ********
# total = 179615
#  == the CLASS of rois distribuided in 2019 are ==
#      class  count  percent  Years
# 0     15  70305    39.14   2019
# 1      4  62840    34.99   2019
# 2      3  28600    15.92   2019
# 3     18  13905     7.74   2019
# 4     12   2785     1.55   2019
# 5     25    985     0.55   2019
# 6     33    195     0.11   2019
#  ******* list of features selected was saved ********
# total = 215778
#  == the CLASS of rois distribuided in 2018 are ==
#      class  count  percent  Years
# 0     15  83544    38.72   2018
# 1      4  76854    35.62   2018
# 2      3  34152    15.83   2018
# 3     18  16320     7.56   2018
# 4     12   3600     1.67   2018
# 5     25   1032     0.48   2018
# 6     33    276     0.13   2018
#  ******* list of features selected was saved ********
# total = 255220
#  == the CLASS of rois distribuided in 2017 are ==
#      class   count  percent  Years
# 0     15  102123    40.01   2017
# 1      4   88753    34.78   2017
# 2      3   39977    15.66   2017
# 3     18   18788     7.36   2017
# 4     12    4032     1.58   2017
# 5     25    1246     0.49   2017
# 6     33     301     0.12   2017
#  ******* list of features selected was saved ********
# total = 233288
#  == the CLASS of rois distribuided in 2016 are ==
#      class  count  percent  Years
# 0     15  92408    39.61   2016
# 1      4  84232    36.11   2016
# 2      3  32944    14.12   2016
# 3     18  19000     8.14   2016
# 4     12   3224     1.38   2016
# 5     25   1184     0.51   2016
# 6     33    296     0.13   2016
#  ******* list of features selected was saved ********
# Loading ==> /content/drive/MyDrive/mapbiomas/featureSelection/shp_ROIs_S2_caat_red/rois_grade_766.csv
#   columns =  Index(['GRID_ID', 'afvi_median', 'afvi_median_dry', 'afvi_median_wet',
#        'avi_median', 'avi_median_dry', 'avi_median_wet', 'awei_median',
#        'awei_median_dry', 'awei_median_wet',
#        ...
#        'swir2_median_dry', 'swir2_median_wet', 'swir2_stdDev', 'ui_median',
#        'ui_median_dry', 'ui_median_wet', 'wetness_median',
#        'wetness_median_dry', 'wetness_median_wet', 'year'],
#       dtype='object', length=127)
#  == Know how many rois have in the table ==
#   year
# 2016    265688
# 2017    231784
# 2018    199668
# 2019    165440
# 2020    131692
# 2021     98016
# 2022     64838
# 2023     32491
# Name: count, dtype: int64
# total = 32491
#  == the CLASS of rois distribuided in 2023 are ==
#      class  count  percent  Years
# 0     15  19307    59.42   2023
# 1      4  10049    30.93   2023
# 2     18   1423     4.38   2023
# 3      3   1251     3.85   2023
# 4     25    217     0.67   2023
# 5     33    124     0.38   2023
# 6     12    120     0.37   2023
#  basin activate 766 and the other Regions processadas
#  ==>  ['7581', '7691', '7625', '7754', '751', '7584', '7614', '7616', '752', '745', '7424', '773', '7612', '7613', '7618', '755', '7617', '7561', '761112', '7564', '7422', '7761', '761111', '7671', '7741', '7615', '76116', '7411', '771', '7712', '757', '753', '7746']
# size dFrame4  (10049, 127)  and the next class maximum is  19457
# temos (41899, 127) filas
#  ====> analisando size of class smaller
#  classe 12 == > size = 120
#  classe 21 == > size = 0
#  classe 22 == > size = 0
#  classe 33 == > size = 124
#  --- will be remove class --- 21
#  --- will be remove class --- 22
# colected Xtrain 2071 | Xtest 39367 | ytrain 2071 | ytest 39367
# colected Xtrain 219 | Xtest 25 | ytrain 219 | ytest 25
#  ==== know we have (2290, 124) to train ====
# class
# 4     0.424454
# 15    0.421397
# 33    0.048472
# 12    0.047162
# 18    0.031004
# 3     0.027511
# Name: proportion, dtype: float64 class
# 4     972
# 15    965
# 33    111
# 12    108
# 18     71
# 3      63
# Name: count, dtype: int64
# #1/20 processing model 0
#   >0 0.804 (0.002)
# #2/20 processing model 1
#   >1 0.808 (0.002)
# #3/20 processing model 2
#   >2 0.809 (0.004)
# #4/20 processing model 3
#   >3 0.900 (0.002)
# #5/20 processing model 4
#   >4 0.804 (0.006)
# #6/20 processing model 5
#   >5 0.810 (0.002)
# #7/20 processing model 6
#   >6 0.829 (0.007)
# #8/20 processing model 7
#   >7 0.912 (0.002)
# #9/20 processing model 8
#   >8 0.807 (0.003)
# #10/20 processing model 9
#   >9 0.807 (0.003)
# #11/20 processing model 10
#   >10 0.860 (0.003)
# #12/20 processing model 11
#   >11 0.911 (0.007)
# #13/20 processing model 12
#   >12 0.807 (0.003)
# #14/20 processing model 13
#   >13 0.806 (0.002)
# #15/20 processing model 14
#   >14 0.876 (0.002)
# #16/20 processing model 15
#   >15 0.911 (0.006)
# #17/20 processing model 16
#   >16 0.808 (0.002)
# #18/20 processing model 17
#   >17 0.822 (0.011)
# #19/20 processing model 18
#   >18 0.873 (0.008)
# #20/20 processing model 19
#   >19 0.915 (0.002)
# model trained in 147.45571234226227 minutos
# total = 32491
#  == the CLASS of rois distribuided in 2023 are ==
#      class  count  percent  Years
# 0     15  19307    59.42   2023
# 1      4  10049    30.93   2023
# 2     18   1423     4.38   2023
# 3      3   1251     3.85   2023
# 4     25    217     0.67   2023
# 5     33    124     0.38   2023
# 6     12    120     0.37   2023
# size dFrame4  (10049, 127)  and the next class maximum is  19457
# temos (41899, 127) filas
#  ====> analisando size of class smaller
#  classe 12 == > size = 120
#  classe 21 == > size = 0
#  classe 22 == > size = 0
#  classe 33 == > size = 124
#  --- will be remove class --- 21
#  --- will be remove class --- 22
# colected Xtrain 2071 | Xtest 39367 | ytrain 2071 | ytest 39367
# colected Xtrain 219 | Xtest 25 | ytrain 219 | ytest 25
#  ==== know we have (2290, 124) to train ====
# class
# 4     0.424454
# 15    0.421397
# 33    0.048472
# 12    0.047162
# 18    0.031004
# 3     0.027511
# Name: proportion, dtype: float64 class
# 4     972
# 15    965
# 33    111
# 12    108
# 18     71
# 3      63
# Name: count, dtype: int64
# Optimal number of features: 41
# model trained in 5.659391093254089 minutos
# quantos features otimos  41
# Addicionando << 29 >> features a mais não ótimas
# quantos features otimos  68
# # 1 ranking 10 | pos 2 >> feature >> afvi_median_wet
# # 2 ranking 1 | pos 5 >> feature >> avi_median_wet
# # 3 ranking 1 | pos 6 >> feature >> awei_median
# # 4 ranking 1 | pos 7 >> feature >> awei_median_dry
# # 5 ranking 14 | pos 8 >> feature >> awei_median_wet
# # 6 ranking 13 | pos 11 >> feature >> blue_median_wet
# # 7 ranking 8 | pos 16 >> feature >> brightness_median
# # 8 ranking 1 | pos 17 >> feature >> brightness_median_dry
# # 9 ranking 1 | pos 18 >> feature >> brightness_median_wet
# # 10 ranking 17 | pos 19 >> feature >> bsi_median
# # 11 ranking 1 | pos 20 >> feature >> bsi_median_1
# # 12 ranking 1 | pos 21 >> feature >> bsi_median_2
# # 13 ranking 1 | pos 24 >> feature >> cvi_median_wet
# # 14 ranking 11 | pos 25 >> feature >> dswi5_median
# # 15 ranking 28 | pos 26 >> feature >> dswi5_median_dry
# # 16 ranking 27 | pos 28 >> feature >> evi_median
# # 17 ranking 1 | pos 29 >> feature >> evi_median_dry
# # 18 ranking 1 | pos 32 >> feature >> gcvi_median_dry
# # 19 ranking 19 | pos 36 >> feature >> gemi_median_wet
# # 20 ranking 18 | pos 38 >> feature >> gli_median_dry
# # 21 ranking 1 | pos 40 >> feature >> green_median
# # 22 ranking 1 | pos 43 >> feature >> green_median_wet
# # 23 ranking 1 | pos 46 >> feature >> gvmi_median
# # 24 ranking 1 | pos 47 >> feature >> gvmi_median_dry
# # 25 ranking 22 | pos 48 >> feature >> gvmi_median_wet
# # 26 ranking 1 | pos 50 >> feature >> iia_median_dry
# # 27 ranking 1 | pos 51 >> feature >> iia_median_wet
# # 28 ranking 15 | pos 52 >> feature >> lswi_median
# # 29 ranking 1 | pos 54 >> feature >> lswi_median_wet
# # 30 ranking 1 | pos 57 >> feature >> mbi_median_wet
# # 31 ranking 20 | pos 59 >> feature >> nddi_median_dry
# # 32 ranking 3 | pos 62 >> feature >> ndvi_median_dry
# # 33 ranking 1 | pos 63 >> feature >> ndvi_median_wet
# # 34 ranking 1 | pos 66 >> feature >> ndwi_median_wet
# # 35 ranking 1 | pos 68 >> feature >> nir_median_contrast
# # 36 ranking 1 | pos 70 >> feature >> nir_median_dry_contrast
# # 37 ranking 1 | pos 71 >> feature >> nir_median_wet
# # 38 ranking 1 | pos 72 >> feature >> osavi_median
# # 39 ranking 1 | pos 76 >> feature >> ratio_median_dry
# # 40 ranking 6 | pos 77 >> feature >> ratio_median_wet
# # 41 ranking 1 | pos 78 >> feature >> red_edge_1_median
# # 42 ranking 7 | pos 79 >> feature >> red_edge_1_median_dry
# # 43 ranking 1 | pos 80 >> feature >> red_edge_1_median_wet
# # 44 ranking 1 | pos 84 >> feature >> red_edge_2_median_wet
# # 45 ranking 1 | pos 88 >> feature >> red_edge_3_median_wet
# # 46 ranking 23 | pos 89 >> feature >> red_edge_3_stdDev
# # 47 ranking 1 | pos 92 >> feature >> red_edge_4_median_wet
# # 48 ranking 25 | pos 95 >> feature >> red_median_contrast
# # 49 ranking 2 | pos 97 >> feature >> red_median_dry_contrast
# # 50 ranking 4 | pos 98 >> feature >> red_median_wet
# # 51 ranking 1 | pos 100 >> feature >> red_stdDev
# # 52 ranking 21 | pos 102 >> feature >> ri_median_dry
# # 53 ranking 24 | pos 103 >> feature >> ri_median_wet
# # 54 ranking 1 | pos 104 >> feature >> rvi_median
# # 55 ranking 12 | pos 105 >> feature >> rvi_median_1
# # 56 ranking 1 | pos 107 >> feature >> shape_median
# # 57 ranking 1 | pos 108 >> feature >> shape_median_dry
# # 58 ranking 1 | pos 110 >> feature >> swir1_median
# # 59 ranking 1 | pos 111 >> feature >> swir1_median_dry
# # 60 ranking 26 | pos 112 >> feature >> swir1_median_wet
# # 61 ranking 1 | pos 114 >> feature >> swir2_median
# # 62 ranking 1 | pos 115 >> feature >> swir2_median_dry
# # 63 ranking 1 | pos 116 >> feature >> swir2_median_wet
# # 64 ranking 9 | pos 117 >> feature >> swir2_stdDev
# # 65 ranking 16 | pos 120 >> feature >> ui_median_wet
# # 66 ranking 5 | pos 121 >> feature >> wetness_median
# # 67 ranking 1 | pos 122 >> feature >> wetness_median_dry
# # 68 ranking 1 | pos 123 >> feature >> wetness_median_wet
# tabela salva em pasta do drive
# total = 64838
#  == the CLASS of rois distribuided in 2022 are ==
#      class  count  percent  Years
# 0     15  38048    58.68   2022
# 1      4  20408    31.48   2022
# 2     18   2846     4.39   2022
# 3      3   2592     4.00   2022
# 4     25    448     0.69   2022
# 5     12    262     0.40   2022
# 6     33    234     0.36   2022
# size dFrame4  (20408, 127)  and the next class maximum is  38198
# temos (82628, 127) filas
#  ====> analisando size of class smaller
#  classe 12 == > size = 262
#  classe 21 == > size = 0
#  classe 22 == > size = 0
#  classe 33 == > size = 234
#  --- will be remove class --- 21
#  --- will be remove class --- 22
# colected Xtrain 4084 | Xtest 77600 | ytrain 4084 | ytest 77600
# colected Xtrain 446 | Xtest 50 | ytrain 446 | ytest 50
#  ==== know we have (4530, 124) to train ====
# class
# 4     0.421634
# 15    0.419868
# 12    0.052097
# 33    0.046358
# 18    0.031347
# 3     0.028698
# Name: proportion, dtype: float64 class
# 4     1910
# 15    1902
# 12     236
# 33     210
# 18     142
# 3      130
# Name: count, dtype: int64
# Optimal number of features: 124
# model trained in 5.414913686116536 minutos
# quantos features otimos  124
# quantos features otimos  124
# # 1 ranking 1 | pos 0 >> feature >> afvi_median
# # 2 ranking 1 | pos 1 >> feature >> afvi_median_dry
# # 3 ranking 1 | pos 2 >> feature >> afvi_median_wet
# # 4 ranking 1 | pos 3 >> feature >> avi_median
# # 5 ranking 1 | pos 4 >> feature >> avi_median_dry
# # 6 ranking 1 | pos 5 >> feature >> avi_median_wet
# # 7 ranking 1 | pos 6 >> feature >> awei_median
# # 8 ranking 1 | pos 7 >> feature >> awei_median_dry
# # 9 ranking 1 | pos 8 >> feature >> awei_median_wet
# # 10 ranking 1 | pos 9 >> feature >> blue_median
# # 11 ranking 1 | pos 10 >> feature >> blue_median_dry
# # 12 ranking 1 | pos 11 >> feature >> blue_median_wet
# # 13 ranking 1 | pos 12 >> feature >> blue_stdDev
# # 14 ranking 1 | pos 13 >> feature >> brba_median
# # 15 ranking 1 | pos 14 >> feature >> brba_median_dry
# # 16 ranking 1 | pos 15 >> feature >> brba_median_wet
# # 17 ranking 1 | pos 16 >> feature >> brightness_median
# # 18 ranking 1 | pos 17 >> feature >> brightness_median_dry
# # 19 ranking 1 | pos 18 >> feature >> brightness_median_wet
# # 20 ranking 1 | pos 19 >> feature >> bsi_median
# # 21 ranking 1 | pos 20 >> feature >> bsi_median_1
# # 22 ranking 1 | pos 21 >> feature >> bsi_median_2
# # 23 ranking 1 | pos 22 >> feature >> cvi_median
# # 24 ranking 1 | pos 23 >> feature >> cvi_median_dry
# # 25 ranking 1 | pos 24 >> feature >> cvi_median_wet
# # 26 ranking 1 | pos 25 >> feature >> dswi5_median
# # 27 ranking 1 | pos 26 >> feature >> dswi5_median_dry
# # 28 ranking 1 | pos 27 >> feature >> dswi5_median_wet
# # 29 ranking 1 | pos 28 >> feature >> evi_median
# # 30 ranking 1 | pos 29 >> feature >> evi_median_dry
# # 31 ranking 1 | pos 30 >> feature >> evi_median_wet
# # 32 ranking 1 | pos 31 >> feature >> gcvi_median
# # 33 ranking 1 | pos 32 >> feature >> gcvi_median_dry
# # 34 ranking 1 | pos 33 >> feature >> gcvi_median_wet
# # 35 ranking 1 | pos 34 >> feature >> gemi_median
# # 36 ranking 1 | pos 35 >> feature >> gemi_median_dry
# # 37 ranking 1 | pos 36 >> feature >> gemi_median_wet
# # 38 ranking 1 | pos 37 >> feature >> gli_median
# # 39 ranking 1 | pos 38 >> feature >> gli_median_dry
# # 40 ranking 1 | pos 39 >> feature >> gli_median_wet
# # 41 ranking 1 | pos 40 >> feature >> green_median
# # 42 ranking 1 | pos 41 >> feature >> green_median_dry
# # 43 ranking 1 | pos 42 >> feature >> green_median_texture
# # 44 ranking 1 | pos 43 >> feature >> green_median_wet
# # 45 ranking 1 | pos 44 >> feature >> green_min
# # 46 ranking 1 | pos 45 >> feature >> green_stdDev
# # 47 ranking 1 | pos 46 >> feature >> gvmi_median
# # 48 ranking 1 | pos 47 >> feature >> gvmi_median_dry
# # 49 ranking 1 | pos 48 >> feature >> gvmi_median_wet
# # 50 ranking 1 | pos 49 >> feature >> iia_median
# # 51 ranking 1 | pos 50 >> feature >> iia_median_dry
# # 52 ranking 1 | pos 51 >> feature >> iia_median_wet
# # 53 ranking 1 | pos 52 >> feature >> lswi_median
# # 54 ranking 1 | pos 53 >> feature >> lswi_median_dry
# # 55 ranking 1 | pos 54 >> feature >> lswi_median_wet
# # 56 ranking 1 | pos 55 >> feature >> mbi_median
# # 57 ranking 1 | pos 56 >> feature >> mbi_median_dry
# # 58 ranking 1 | pos 57 >> feature >> mbi_median_wet
# # 59 ranking 1 | pos 58 >> feature >> nddi_median
# # 60 ranking 1 | pos 59 >> feature >> nddi_median_dry
# # 61 ranking 1 | pos 60 >> feature >> nddi_median_wet
# # 62 ranking 1 | pos 61 >> feature >> ndvi_median
# # 63 ranking 1 | pos 62 >> feature >> ndvi_median_dry
# # 64 ranking 1 | pos 63 >> feature >> ndvi_median_wet
# # 65 ranking 1 | pos 64 >> feature >> ndwi_median
# # 66 ranking 1 | pos 65 >> feature >> ndwi_median_dry
# # 67 ranking 1 | pos 66 >> feature >> ndwi_median_wet
# # 68 ranking 1 | pos 67 >> feature >> nir_median
# # 69 ranking 1 | pos 68 >> feature >> nir_median_contrast
# # 70 ranking 1 | pos 69 >> feature >> nir_median_dry
# # 71 ranking 1 | pos 70 >> feature >> nir_median_dry_contrast
# # 72 ranking 1 | pos 71 >> feature >> nir_median_wet
# # 73 ranking 1 | pos 72 >> feature >> osavi_median
# # 74 ranking 1 | pos 73 >> feature >> osavi_median_dry
# # 75 ranking 1 | pos 74 >> feature >> osavi_median_wet
# # 76 ranking 1 | pos 75 >> feature >> ratio_median
# # 77 ranking 1 | pos 76 >> feature >> ratio_median_dry
# # 78 ranking 1 | pos 77 >> feature >> ratio_median_wet
# # 79 ranking 1 | pos 78 >> feature >> red_edge_1_median
# # 80 ranking 1 | pos 79 >> feature >> red_edge_1_median_dry
# # 81 ranking 1 | pos 80 >> feature >> red_edge_1_median_wet
# # 82 ranking 1 | pos 81 >> feature >> red_edge_1_stdDev
# # 83 ranking 1 | pos 82 >> feature >> red_edge_2_median
# # 84 ranking 1 | pos 83 >> feature >> red_edge_2_median_dry
# # 85 ranking 1 | pos 84 >> feature >> red_edge_2_median_wet
# # 86 ranking 1 | pos 85 >> feature >> red_edge_2_stdDev
# # 87 ranking 1 | pos 86 >> feature >> red_edge_3_median
# # 88 ranking 1 | pos 87 >> feature >> red_edge_3_median_dry
# # 89 ranking 1 | pos 88 >> feature >> red_edge_3_median_wet
# # 90 ranking 1 | pos 89 >> feature >> red_edge_3_stdDev
# # 91 ranking 1 | pos 90 >> feature >> red_edge_4_median
# # 92 ranking 1 | pos 91 >> feature >> red_edge_4_median_dry
# # 93 ranking 1 | pos 92 >> feature >> red_edge_4_median_wet
# # 94 ranking 1 | pos 93 >> feature >> red_edge_4_stdDev
# # 95 ranking 1 | pos 94 >> feature >> red_median
# # 96 ranking 1 | pos 95 >> feature >> red_median_contrast
# # 97 ranking 1 | pos 96 >> feature >> red_median_dry
# # 98 ranking 1 | pos 97 >> feature >> red_median_dry_contrast
# # 99 ranking 1 | pos 98 >> feature >> red_median_wet
# # 100 ranking 1 | pos 99 >> feature >> red_min
# # 101 ranking 1 | pos 100 >> feature >> red_stdDev
# # 102 ranking 1 | pos 101 >> feature >> ri_median
# # 103 ranking 1 | pos 102 >> feature >> ri_median_dry
# # 104 ranking 1 | pos 103 >> feature >> ri_median_wet
# # 105 ranking 1 | pos 104 >> feature >> rvi_median
# # 106 ranking 1 | pos 105 >> feature >> rvi_median_1
# # 107 ranking 1 | pos 106 >> feature >> rvi_median_wet
# # 108 ranking 1 | pos 107 >> feature >> shape_median
# # 109 ranking 1 | pos 108 >> feature >> shape_median_dry
# # 110 ranking 1 | pos 109 >> feature >> shape_median_wet
# # 111 ranking 1 | pos 110 >> feature >> swir1_median
# # 112 ranking 1 | pos 111 >> feature >> swir1_median_dry
# # 113 ranking 1 | pos 112 >> feature >> swir1_median_wet
# # 114 ranking 1 | pos 113 >> feature >> swir1_stdDev
# # 115 ranking 1 | pos 114 >> feature >> swir2_median
# # 116 ranking 1 | pos 115 >> feature >> swir2_median_dry
# # 117 ranking 1 | pos 116 >> feature >> swir2_median_wet
# # 118 ranking 1 | pos 117 >> feature >> swir2_stdDev
# # 119 ranking 1 | pos 118 >> feature >> ui_median
# # 120 ranking 1 | pos 119 >> feature >> ui_median_dry
# # 121 ranking 1 | pos 120 >> feature >> ui_median_wet
# # 122 ranking 1 | pos 121 >> feature >> wetness_median
# # 123 ranking 1 | pos 122 >> feature >> wetness_median_dry
# # 124 ranking 1 | pos 123 >> feature >> wetness_median_wet
# tabela salva em pasta do drive
# total = 98016
#  == the CLASS of rois distribuided in 2021 are ==
#      class  count  percent  Years
# 0     15  57654    58.82   2021
# 1      4  30906    31.53   2021
# 2      3   4113     4.20   2021
# 3     18   3966     4.05   2021
# 4     25    588     0.60   2021
# 5     12    396     0.40   2021
# 6     33    393     0.40   2021
# size dFrame4  (30906, 127)  and the next class maximum is  57804
# temos (124914, 127) filas
#  ====> analisando size of class smaller
#  classe 12 == > size = 396
#  classe 21 == > size = 0
#  classe 22 == > size = 0
#  classe 33 == > size = 393
#  --- will be remove class --- 21
#  --- will be remove class --- 22
# colected Xtrain 6176 | Xtest 117361 | ytrain 6176 | ytest 117361
# colected Xtrain 710 | Xtest 79 | ytrain 710 | ytest 79
#  ==== know we have (6886, 124) to train ====
# class
# 4     0.419692
# 15    0.418530
# 12    0.051699
# 33    0.051409
# 3     0.029916
# 18    0.028754
# Name: proportion, dtype: float64 class
# 4     2890
# 15    2882
# 12     356
# 33     354
# 3      206
# 18     198
# Name: count, dtype: int64
# Optimal number of features: 45
# model trained in 16.007297285397847 minutos
# quantos features otimos  45
# Addicionando << 25 >> features a mais não ótimas
# quantos features otimos  68
# # 1 ranking 1 | pos 2 >> feature >> afvi_median_wet
# # 2 ranking 19 | pos 5 >> feature >> avi_median_wet
# # 3 ranking 1 | pos 6 >> feature >> awei_median
# # 4 ranking 1 | pos 7 >> feature >> awei_median_dry
# # 5 ranking 1 | pos 8 >> feature >> awei_median_wet
# # 6 ranking 9 | pos 9 >> feature >> blue_median
# # 7 ranking 24 | pos 10 >> feature >> blue_median_dry
# # 8 ranking 3 | pos 13 >> feature >> brba_median
# # 9 ranking 4 | pos 16 >> feature >> brightness_median
# # 10 ranking 1 | pos 17 >> feature >> brightness_median_dry
# # 11 ranking 2 | pos 18 >> feature >> brightness_median_wet
# # 12 ranking 1 | pos 24 >> feature >> cvi_median_wet
# # 13 ranking 6 | pos 25 >> feature >> dswi5_median
# # 14 ranking 1 | pos 26 >> feature >> dswi5_median_dry
# # 15 ranking 14 | pos 27 >> feature >> dswi5_median_wet
# # 16 ranking 1 | pos 29 >> feature >> evi_median_dry
# # 17 ranking 5 | pos 30 >> feature >> evi_median_wet
# # 18 ranking 1 | pos 32 >> feature >> gcvi_median_dry
# # 19 ranking 1 | pos 33 >> feature >> gcvi_median_wet
# # 20 ranking 1 | pos 36 >> feature >> gemi_median_wet
# # 21 ranking 1 | pos 40 >> feature >> green_median
# # 22 ranking 1 | pos 41 >> feature >> green_median_dry
# # 23 ranking 1 | pos 43 >> feature >> green_median_wet
# # 24 ranking 21 | pos 46 >> feature >> gvmi_median
# # 25 ranking 1 | pos 47 >> feature >> gvmi_median_dry
# # 26 ranking 1 | pos 50 >> feature >> iia_median_dry
# # 27 ranking 1 | pos 51 >> feature >> iia_median_wet
# # 28 ranking 16 | pos 53 >> feature >> lswi_median_dry
# # 29 ranking 1 | pos 54 >> feature >> lswi_median_wet
# # 30 ranking 8 | pos 55 >> feature >> mbi_median
# # 31 ranking 1 | pos 62 >> feature >> ndvi_median_dry
# # 32 ranking 1 | pos 63 >> feature >> ndvi_median_wet
# # 33 ranking 1 | pos 66 >> feature >> ndwi_median_wet
# # 34 ranking 1 | pos 68 >> feature >> nir_median_contrast
# # 35 ranking 1 | pos 70 >> feature >> nir_median_dry_contrast
# # 36 ranking 1 | pos 71 >> feature >> nir_median_wet
# # 37 ranking 20 | pos 72 >> feature >> osavi_median
# # 38 ranking 18 | pos 73 >> feature >> osavi_median_dry
# # 39 ranking 1 | pos 76 >> feature >> ratio_median_dry
# # 40 ranking 1 | pos 77 >> feature >> ratio_median_wet
# # 41 ranking 1 | pos 78 >> feature >> red_edge_1_median
# # 42 ranking 1 | pos 79 >> feature >> red_edge_1_median_dry
# # 43 ranking 1 | pos 80 >> feature >> red_edge_1_median_wet
# # 44 ranking 1 | pos 82 >> feature >> red_edge_2_median
# # 45 ranking 23 | pos 83 >> feature >> red_edge_2_median_dry
# # 46 ranking 1 | pos 84 >> feature >> red_edge_2_median_wet
# # 47 ranking 1 | pos 85 >> feature >> red_edge_2_stdDev
# # 48 ranking 1 | pos 88 >> feature >> red_edge_3_median_wet
# # 49 ranking 1 | pos 92 >> feature >> red_edge_4_median_wet
# # 50 ranking 17 | pos 93 >> feature >> red_edge_4_stdDev
# # 51 ranking 11 | pos 94 >> feature >> red_median
# # 52 ranking 10 | pos 96 >> feature >> red_median_dry
# # 53 ranking 13 | pos 97 >> feature >> red_median_dry_contrast
# # 54 ranking 1 | pos 98 >> feature >> red_median_wet
# # 55 ranking 12 | pos 102 >> feature >> ri_median_dry
# # 56 ranking 22 | pos 104 >> feature >> rvi_median
# # 57 ranking 1 | pos 105 >> feature >> rvi_median_1
# # 58 ranking 1 | pos 106 >> feature >> rvi_median_wet
# # 59 ranking 1 | pos 110 >> feature >> swir1_median
# # 60 ranking 1 | pos 111 >> feature >> swir1_median_dry
# # 61 ranking 15 | pos 113 >> feature >> swir1_stdDev
# # 62 ranking 1 | pos 114 >> feature >> swir2_median
# # 63 ranking 1 | pos 115 >> feature >> swir2_median_dry
# # 64 ranking 1 | pos 116 >> feature >> swir2_median_wet
# # 65 ranking 1 | pos 117 >> feature >> swir2_stdDev
# # 66 ranking 7 | pos 120 >> feature >> ui_median_wet
# # 67 ranking 1 | pos 121 >> feature >> wetness_median
# # 68 ranking 1 | pos 122 >> feature >> wetness_median_dry
# tabela salva em pasta do drive
# total = 131692
#  == the CLASS of rois distribuided in 2020 are ==
#      class  count  percent  Years
# 0     15  77428    58.79   2020
# 1      4  42384    32.18   2020
# 2      3   5400     4.10   2020
# 3     18   4560     3.46   2020
# 4     25    840     0.64   2020
# 5     12    592     0.45   2020
# 6     33    488     0.37   2020
# size dFrame4  (42384, 127)  and the next class maximum is  77578
# temos (166886, 127) filas
#  ====> analisando size of class smaller
#  classe 12 == > size = 592
#  classe 21 == > size = 0
#  classe 22 == > size = 0
#  classe 33 == > size = 488
#  --- will be remove class --- 21
#  --- will be remove class --- 22
# colected Xtrain 8248 | Xtest 156718 | ytrain 8248 | ytest 156718
# colected Xtrain 972 | Xtest 108 | ytrain 972 | ytest 108
#  ==== know we have (9220, 124) to train ====
# class
# 4     0.420716
# 15    0.419848
# 12    0.057809
# 33    0.047614
# 3     0.029284
# 18    0.024729
# Name: proportion, dtype: float64 class
# 4     3879
# 15    3871
# 12     533
# 33     439
# 3      270
# 18     228
# Name: count, dtype: int64
# Optimal number of features: 68
# model trained in 18.228685847918193 minutos
# quantos features otimos  68
# Addicionando << 2 >> features a mais não ótimas
# quantos features otimos  68
# # 1 ranking 1 | pos 1 >> feature >> afvi_median_dry
# # 2 ranking 1 | pos 4 >> feature >> avi_median_dry
# # 3 ranking 1 | pos 5 >> feature >> avi_median_wet
# # 4 ranking 1 | pos 6 >> feature >> awei_median
# # 5 ranking 1 | pos 7 >> feature >> awei_median_dry
# # 6 ranking 1 | pos 9 >> feature >> blue_median
# # 7 ranking 1 | pos 10 >> feature >> blue_median_dry
# # 8 ranking 1 | pos 11 >> feature >> blue_median_wet
# # 9 ranking 1 | pos 13 >> feature >> brba_median
# # 10 ranking 1 | pos 14 >> feature >> brba_median_dry
# # 11 ranking 1 | pos 16 >> feature >> brightness_median
# # 12 ranking 1 | pos 17 >> feature >> brightness_median_dry
# # 13 ranking 1 | pos 18 >> feature >> brightness_median_wet
# # 14 ranking 1 | pos 21 >> feature >> bsi_median_2
# # 15 ranking 1 | pos 24 >> feature >> cvi_median_wet
# # 16 ranking 1 | pos 27 >> feature >> dswi5_median_wet
# # 17 ranking 1 | pos 28 >> feature >> evi_median
# # 18 ranking 1 | pos 29 >> feature >> evi_median_dry
# # 19 ranking 1 | pos 33 >> feature >> gcvi_median_wet
# # 20 ranking 1 | pos 36 >> feature >> gemi_median_wet
# # 21 ranking 1 | pos 39 >> feature >> gli_median_wet
# # 22 ranking 1 | pos 40 >> feature >> green_median
# # 23 ranking 1 | pos 43 >> feature >> green_median_wet
# # 24 ranking 1 | pos 46 >> feature >> gvmi_median
# # 25 ranking 1 | pos 47 >> feature >> gvmi_median_dry
# # 26 ranking 1 | pos 50 >> feature >> iia_median_dry
# # 27 ranking 1 | pos 51 >> feature >> iia_median_wet
# # 28 ranking 1 | pos 54 >> feature >> lswi_median_wet
# # 29 ranking 1 | pos 55 >> feature >> mbi_median
# ...
# # 4 ranking 1 | pos 7 >> feature >> awei_median_dry
# # 5 ranking 1 | pos 8 >> feature >> awei_median_wet
# # 6 ranking 1 | pos 9 >> feature >> blue_median
# # 7 ranking 4 | pos 13 >> feature >> brba_median
# # 8 ranking 1 | pos 15 >> feature >> brba_median_wet
# # 9 ranking 1 | pos 16 >> feature >> brightness_median
# # 10 ranking 1 | pos 17 >> feature >> brightness_median_dry
# # 11 ranking 1 | pos 19 >> feature >> bsi_median
# # 12 ranking 1 | pos 20 >> feature >> bsi_median_1
# # 13 ranking 1 | pos 21 >> feature >> bsi_median_2
# # 14 ranking 1 | pos 27 >> feature >> dswi5_median_wet
# # 15 ranking 1 | pos 28 >> feature >> evi_median
# # 16 ranking 1 | pos 29 >> feature >> evi_median_dry
# # 17 ranking 5 | pos 30 >> feature >> evi_median_wet
# # 18 ranking 1 | pos 34 >> feature >> gemi_median
# # 19 ranking 3 | pos 36 >> feature >> gemi_median_wet
# # 20 ranking 1 | pos 37 >> feature >> gli_median
# # 21 ranking 1 | pos 39 >> feature >> gli_median_wet
# # 22 ranking 1 | pos 40 >> feature >> green_median
# # 23 ranking 1 | pos 43 >> feature >> green_median_wet
# # 24 ranking 1 | pos 44 >> feature >> green_min
# # 25 ranking 1 | pos 46 >> feature >> gvmi_median
# # 26 ranking 1 | pos 47 >> feature >> gvmi_median_dry
# # 27 ranking 1 | pos 48 >> feature >> gvmi_median_wet
# # 28 ranking 6 | pos 53 >> feature >> lswi_median_dry
# # 29 ranking 1 | pos 55 >> feature >> mbi_median
# # 30 ranking 1 | pos 56 >> feature >> mbi_median_dry
# # 31 ranking 1 | pos 57 >> feature >> mbi_median_wet
# # 32 ranking 1 | pos 58 >> feature >> nddi_median
# # 33 ranking 1 | pos 63 >> feature >> ndvi_median_wet
# # 34 ranking 1 | pos 68 >> feature >> nir_median_contrast
# # 35 ranking 1 | pos 71 >> feature >> nir_median_wet
# # 36 ranking 1 | pos 72 >> feature >> osavi_median
# # 37 ranking 1 | pos 73 >> feature >> osavi_median_dry
# # 38 ranking 1 | pos 74 >> feature >> osavi_median_wet
# # 39 ranking 1 | pos 77 >> feature >> ratio_median_wet
# # 40 ranking 1 | pos 78 >> feature >> red_edge_1_median
# # 41 ranking 1 | pos 80 >> feature >> red_edge_1_median_wet
# # 42 ranking 1 | pos 81 >> feature >> red_edge_1_stdDev
# # 43 ranking 1 | pos 82 >> feature >> red_edge_2_median
# # 44 ranking 1 | pos 84 >> feature >> red_edge_2_median_wet
# # 45 ranking 1 | pos 85 >> feature >> red_edge_2_stdDev
# # 46 ranking 1 | pos 88 >> feature >> red_edge_3_median_wet
# # 47 ranking 1 | pos 89 >> feature >> red_edge_3_stdDev
# # 48 ranking 1 | pos 90 >> feature >> red_edge_4_median
# # 49 ranking 1 | pos 92 >> feature >> red_edge_4_median_wet
# # 50 ranking 1 | pos 94 >> feature >> red_median
# # 51 ranking 1 | pos 95 >> feature >> red_median_contrast
# # 52 ranking 1 | pos 96 >> feature >> red_median_dry
# # 53 ranking 1 | pos 99 >> feature >> red_min
# # 54 ranking 1 | pos 100 >> feature >> red_stdDev
# # 55 ranking 7 | pos 105 >> feature >> rvi_median_1
# # 56 ranking 1 | pos 106 >> feature >> rvi_median_wet
# # 57 ranking 1 | pos 107 >> feature >> shape_median
# # 58 ranking 1 | pos 109 >> feature >> shape_median_wet
# # 59 ranking 1 | pos 110 >> feature >> swir1_median
# # 60 ranking 2 | pos 112 >> feature >> swir1_median_wet
# # 61 ranking 1 | pos 113 >> feature >> swir1_stdDev
# # 62 ranking 1 | pos 114 >> feature >> swir2_median
# # 63 ranking 1 | pos 115 >> feature >> swir2_median_dry
# # 64 ranking 1 | pos 116 >> feature >> swir2_median_wet
# # 65 ranking 1 | pos 117 >> feature >> swir2_stdDev
# # 66 ranking 1 | pos 121 >> feature >> wetness_median
# # 67 ranking 1 | pos 122 >> feature >> wetness_median_dry
# # 68 ranking 1 | pos 123 >> feature >> wetness_median_wet
# tabela salva em pasta do drive
# total = 245350
#  == the CLASS of rois distribuided in 2017 are ==
#      class   count  percent  Years
# 0     15  158480    64.59   2017
# 1      4   62636    25.53   2017
# 2      3   14196     5.79   2017
# 3     18    8624     3.51   2017
# 4     25    1036     0.42   2017
# 5     33     301     0.12   2017
# 6     12      77     0.03   2017
# size dFrame4  (62636, 127)  and the next class maximum is  158630
# temos (341344, 127) filas
#  ====> analisando size of class smaller
#  classe 12 == > size = 77
#  classe 21 == > size = 0
#  classe 22 == > size = 0
#  classe 33 == > size = 301
#  --- will be remove class --- 21
#  --- will be remove class --- 22
# colected Xtrain 16996 | Xtest 322934 | ytrain 16996 | ytest 322934
# colected Xtrain 340 | Xtest 38 | ytrain 340 | ytest 38
#  ==== know we have (17336, 124) to train ====
# class
# 4     0.457487
# 15    0.457084
# 3     0.040955
# 18    0.024862
# 33    0.015632
# 12    0.003980
# Name: proportion, dtype: float64 class
# 4     7931
# 15    7924
# 3      710
# 18     431
# 33     271
# 12      69
# Name: count, dtype: int64
# Optimal number of features: 42
# model trained in 27.655888656775158 minutos
# quantos features otimos  42
# Addicionando << 28 >> features a mais não ótimas
# quantos features otimos  68
# # 1 ranking 1 | pos 0 >> feature >> afvi_median
# # 2 ranking 1 | pos 3 >> feature >> avi_median
# # 3 ranking 1 | pos 5 >> feature >> avi_median_wet
# # 4 ranking 1 | pos 6 >> feature >> awei_median
# # 5 ranking 20 | pos 7 >> feature >> awei_median_dry
# # 6 ranking 1 | pos 8 >> feature >> awei_median_wet
# # 7 ranking 27 | pos 9 >> feature >> blue_median
# # 8 ranking 1 | pos 11 >> feature >> blue_median_wet
# # 9 ranking 10 | pos 13 >> feature >> brba_median
# # 10 ranking 22 | pos 15 >> feature >> brba_median_wet
# # 11 ranking 1 | pos 16 >> feature >> brightness_median
# # 12 ranking 8 | pos 18 >> feature >> brightness_median_wet
# # 13 ranking 7 | pos 20 >> feature >> bsi_median_1
# # 14 ranking 1 | pos 24 >> feature >> cvi_median_wet
# # 15 ranking 5 | pos 27 >> feature >> dswi5_median_wet
# # 16 ranking 19 | pos 29 >> feature >> evi_median_dry
# # 17 ranking 1 | pos 30 >> feature >> evi_median_wet
# # 18 ranking 1 | pos 34 >> feature >> gemi_median
# # 19 ranking 6 | pos 36 >> feature >> gemi_median_wet
# # 20 ranking 3 | pos 37 >> feature >> gli_median
# # 21 ranking 1 | pos 39 >> feature >> gli_median_wet
# # 22 ranking 21 | pos 40 >> feature >> green_median
# # 23 ranking 1 | pos 43 >> feature >> green_median_wet
# # 24 ranking 1 | pos 46 >> feature >> gvmi_median
# # 25 ranking 1 | pos 48 >> feature >> gvmi_median_wet
# # 26 ranking 14 | pos 53 >> feature >> lswi_median_dry
# # 27 ranking 1 | pos 55 >> feature >> mbi_median
# # 28 ranking 1 | pos 57 >> feature >> mbi_median_wet
# # 29 ranking 13 | pos 58 >> feature >> nddi_median
# # 30 ranking 1 | pos 60 >> feature >> nddi_median_wet
# # 31 ranking 16 | pos 61 >> feature >> ndvi_median
# # 32 ranking 17 | pos 64 >> feature >> ndwi_median
# # 33 ranking 24 | pos 65 >> feature >> ndwi_median_dry
# # 34 ranking 26 | pos 66 >> feature >> ndwi_median_wet
# # 35 ranking 9 | pos 67 >> feature >> nir_median
# # 36 ranking 1 | pos 68 >> feature >> nir_median_contrast
# # 37 ranking 1 | pos 71 >> feature >> nir_median_wet
# # 38 ranking 1 | pos 72 >> feature >> osavi_median
# # 39 ranking 1 | pos 73 >> feature >> osavi_median_dry
# # 40 ranking 1 | pos 75 >> feature >> ratio_median
# # 41 ranking 4 | pos 76 >> feature >> ratio_median_dry
# # 42 ranking 1 | pos 80 >> feature >> red_edge_1_median_wet
# # 43 ranking 15 | pos 81 >> feature >> red_edge_1_stdDev
# # 44 ranking 1 | pos 82 >> feature >> red_edge_2_median
# # 45 ranking 1 | pos 84 >> feature >> red_edge_2_median_wet
# # 46 ranking 11 | pos 85 >> feature >> red_edge_2_stdDev
# # 47 ranking 1 | pos 86 >> feature >> red_edge_3_median
# # 48 ranking 1 | pos 88 >> feature >> red_edge_3_median_wet
# # 49 ranking 1 | pos 89 >> feature >> red_edge_3_stdDev
# # 50 ranking 23 | pos 90 >> feature >> red_edge_4_median
# # 51 ranking 2 | pos 92 >> feature >> red_edge_4_median_wet
# # 52 ranking 1 | pos 93 >> feature >> red_edge_4_stdDev
# # 53 ranking 25 | pos 94 >> feature >> red_median
# # 54 ranking 1 | pos 95 >> feature >> red_median_contrast
# # 55 ranking 1 | pos 98 >> feature >> red_median_wet
# # 56 ranking 1 | pos 100 >> feature >> red_stdDev
# # 57 ranking 18 | pos 107 >> feature >> shape_median
# # 58 ranking 1 | pos 109 >> feature >> shape_median_wet
# # 59 ranking 1 | pos 110 >> feature >> swir1_median
# # 60 ranking 12 | pos 112 >> feature >> swir1_median_wet
# # 61 ranking 1 | pos 113 >> feature >> swir1_stdDev
# # 62 ranking 1 | pos 114 >> feature >> swir2_median
# # 63 ranking 1 | pos 115 >> feature >> swir2_median_dry
# # 64 ranking 1 | pos 116 >> feature >> swir2_median_wet
# # 65 ranking 1 | pos 117 >> feature >> swir2_stdDev
# # 66 ranking 1 | pos 119 >> feature >> ui_median_dry
# # 67 ranking 1 | pos 121 >> feature >> wetness_median
# # 68 ranking 1 | pos 123 >> feature >> wetness_median_wet
# tabela salva em pasta do drive
# total = 275592
#  == the CLASS of rois distribuided in 2016 are ==
#      class   count  percent  Years
# 0     15  176752    64.14   2016
# 1      4   72048    26.14   2016
# 2      3   15816     5.74   2016
# 3     18    9192     3.34   2016
# 4     25    1424     0.52   2016
# 5     33     256     0.09   2016
# 6     12     104     0.04   2016
# size dFrame4  (72048, 127)  and the next class maximum is  176902
# temos (380446, 127) filas
#  ====> analisando size of class smaller
#  classe 12 == > size = 104
#  classe 21 == > size = 0
#  classe 22 == > size = 0
#  classe 33 == > size = 256
#  --- will be remove class --- 21
#  --- will be remove class --- 22
# colected Xtrain 18933 | Xtest 359729 | ytrain 18933 | ytest 359729
# colected Xtrain 324 | Xtest 36 | ytrain 324 | ytest 36
#  ==== know we have (19257, 124) to train ====
# class
# 4     0.459313
# 15    0.458898
# 3     0.041076
# 18    0.023887
# 33    0.011944
# 12    0.004881
# Name: proportion, dtype: float64 class
# 4     8845
# 15    8837
# 3      791
# 18     460
# 33     230
# 12      94
# Name: count, dtype: int64
# Optimal number of features: 64
# model trained in 26.45154365301132 minutos
# quantos features otimos  64
# Addicionando << 6 >> features a mais não ótimas
# quantos features otimos  68
# # 1 ranking 1 | pos 2 >> feature >> afvi_median_wet
# # 2 ranking 2 | pos 4 >> feature >> avi_median_dry
# # 3 ranking 1 | pos 6 >> feature >> awei_median
# # 4 ranking 1 | pos 8 >> feature >> awei_median_wet
# # 5 ranking 1 | pos 9 >> feature >> blue_median
# # 6 ranking 1 | pos 10 >> feature >> blue_median_dry
# # 7 ranking 1 | pos 16 >> feature >> brightness_median
# # 8 ranking 1 | pos 17 >> feature >> brightness_median_dry
# # 9 ranking 1 | pos 18 >> feature >> brightness_median_wet
# # 10 ranking 1 | pos 22 >> feature >> cvi_median
# # 11 ranking 1 | pos 24 >> feature >> cvi_median_wet
# # 12 ranking 1 | pos 26 >> feature >> dswi5_median_dry
# # 13 ranking 1 | pos 28 >> feature >> evi_median
# # 14 ranking 1 | pos 29 >> feature >> evi_median_dry
# # 15 ranking 1 | pos 30 >> feature >> evi_median_wet
# # 16 ranking 1 | pos 31 >> feature >> gcvi_median
# # 17 ranking 1 | pos 32 >> feature >> gcvi_median_dry
# # 18 ranking 1 | pos 33 >> feature >> gcvi_median_wet
# # 19 ranking 5 | pos 35 >> feature >> gemi_median_dry
# # 20 ranking 1 | pos 37 >> feature >> gli_median
# # 21 ranking 1 | pos 39 >> feature >> gli_median_wet
# # 22 ranking 1 | pos 40 >> feature >> green_median
# # 23 ranking 1 | pos 41 >> feature >> green_median_dry
# # 24 ranking 1 | pos 43 >> feature >> green_median_wet
# # 25 ranking 1 | pos 44 >> feature >> green_min
# # 26 ranking 1 | pos 46 >> feature >> gvmi_median
# # 27 ranking 1 | pos 47 >> feature >> gvmi_median_dry
# # 28 ranking 1 | pos 48 >> feature >> gvmi_median_wet
# # 29 ranking 1 | pos 51 >> feature >> iia_median_wet
# # 30 ranking 1 | pos 53 >> feature >> lswi_median_dry
# # 31 ranking 4 | pos 55 >> feature >> mbi_median
# # 32 ranking 1 | pos 56 >> feature >> mbi_median_dry
# # 33 ranking 1 | pos 57 >> feature >> mbi_median_wet
# # 34 ranking 1 | pos 58 >> feature >> nddi_median
# # 35 ranking 1 | pos 59 >> feature >> nddi_median_dry
# # 36 ranking 1 | pos 60 >> feature >> nddi_median_wet
# # 37 ranking 1 | pos 61 >> feature >> ndvi_median
# # 38 ranking 1 | pos 66 >> feature >> ndwi_median_wet
# # 39 ranking 1 | pos 68 >> feature >> nir_median_contrast
# # 40 ranking 1 | pos 70 >> feature >> nir_median_dry_contrast
# # 41 ranking 1 | pos 72 >> feature >> osavi_median
# # 42 ranking 1 | pos 73 >> feature >> osavi_median_dry
# # 43 ranking 1 | pos 74 >> feature >> osavi_median_wet
# # 44 ranking 1 | pos 78 >> feature >> red_edge_1_median
# # 45 ranking 1 | pos 81 >> feature >> red_edge_1_stdDev
# # 46 ranking 1 | pos 91 >> feature >> red_edge_4_median_dry
# # 47 ranking 3 | pos 92 >> feature >> red_edge_4_median_wet
# # 48 ranking 1 | pos 94 >> feature >> red_median
# # 49 ranking 1 | pos 95 >> feature >> red_median_contrast
# # 50 ranking 1 | pos 97 >> feature >> red_median_dry_contrast
# # 51 ranking 1 | pos 98 >> feature >> red_median_wet
# # 52 ranking 1 | pos 99 >> feature >> red_min
# # 53 ranking 1 | pos 100 >> feature >> red_stdDev
# # 54 ranking 1 | pos 101 >> feature >> ri_median
# # 55 ranking 1 | pos 103 >> feature >> ri_median_wet
# # 56 ranking 1 | pos 105 >> feature >> rvi_median_1
# # 57 ranking 1 | pos 109 >> feature >> shape_median_wet
# # 58 ranking 1 | pos 110 >> feature >> swir1_median
# # 59 ranking 1 | pos 111 >> feature >> swir1_median_dry
# # 60 ranking 1 | pos 112 >> feature >> swir1_median_wet
# # 61 ranking 1 | pos 113 >> feature >> swir1_stdDev
# # 62 ranking 1 | pos 114 >> feature >> swir2_median
# # 63 ranking 1 | pos 116 >> feature >> swir2_median_wet
# # 64 ranking 1 | pos 117 >> feature >> swir2_stdDev
# # 65 ranking 1 | pos 120 >> feature >> ui_median_wet
# # 66 ranking 1 | pos 121 >> feature >> wetness_median
# # 67 ranking 1 | pos 122 >> feature >> wetness_median_dry
# # 68 ranking 1 | pos 123 >> feature >> wetness_median_wet
# tabela salva em pasta do drive
# Loading ==> /content/drive/MyDrive/mapbiomas/featureSelection/shp_ROIs_S2_caat_red/rois_grade_764.csv
#   columns =  Index(['GRID_ID', 'afvi_median', 'afvi_median_dry', 'afvi_median_wet',
#        'avi_median', 'avi_median_dry', 'avi_median_wet', 'awei_median',
#        'awei_median_dry', 'awei_median_wet',
#        ...
#        'swir2_median_dry', 'swir2_median_wet', 'swir2_stdDev', 'ui_median',
#        'ui_median_dry', 'ui_median_wet', 'wetness_median',
#        'wetness_median_dry', 'wetness_median_wet', 'year'],
#       dtype='object', length=127)
#  == Know how many rois have in the table ==
#   year
# 2016    199976
# 2017    183083
# 2018    157933
# 2019    135768
# 2020    114096
# 2021     79522
# 2022     52506
# 2023     26330
# Name: count, dtype: int64
# total = 26330
#  == the CLASS of rois distribuided in 2023 are ==
#      class  count  percent  Years
# 0      4  11304    42.93   2023
# 1     15   6357    24.14   2023
# 2     18   5791    21.99   2023
# 3     12   1781     6.76   2023
# 4      3    918     3.49   2023
# 5     25    111     0.42   2023
# 6     33     60     0.23   2023
# 7     21      8     0.03   2023
#  basin activate 764 and the other Regions processadas
#  ==>  ['7581', '7691', '7625', '7754', '751', '7584', '7614', '7616', '752', '745', '7424', '773', '7612', '7613', '7618', '755', '7617', '7561', '761112', '7564', '7422', '7761', '761111', '7671', '7741', '7615', '76116', '7411', '771', '7712', '757', '753', '7746', '766', '7764', '772', '7721']
# size dFrame4  (11304, 127)  and the next class maximum is  6507
# temos (21533, 127) filas
#  ====> analisando size of class smaller
#  classe 12 == > size = 1781
#  classe 21 == > size = 8
#  classe 22 == > size = 0
#  classe 33 == > size = 60
#  --- will be remove class --- 22
# colected Xtrain 978 | Xtest 18595 | ytrain 978 | ytest 18595
# colected Xtrain 1664 | Xtest 185 | ytrain 1664 | ytest 185
#  ==== know we have (2642, 124) to train ====
# class
# 12    0.606737
# 4     0.123013
# 15    0.120363
# 18    0.109387
# 33    0.020439
# 3     0.017411
# 21    0.002650
# Name: proportion, dtype: float64 class
# 12    1603
# 4      325
# 15     318
# 18     289
# 33      54
# 3       46
# 21       7
# Name: count, dtype: int64
# #1/20 processing model 0
#   >0 0.607 (0.000)
# #2/20 processing model 1
#   >1 0.607 (0.000)
# #3/20 processing model 2
#   >2 0.607 (0.000)
# #4/20 processing model 3
#   >3 0.889 (0.009)
# #5/20 processing model 4
#   >4 0.607 (0.000)
# #6/20 processing model 5
#   >5 0.607 (0.000)
# #7/20 processing model 6
#   >6 0.614 (0.008)
# #8/20 processing model 7
#   >7 0.894 (0.008)
# #9/20 processing model 8
#   >8 0.607 (0.000)
# #10/20 processing model 9
#   >9 0.607 (0.000)
# #11/20 processing model 10
#   >10 0.754 (0.008)
# #12/20 processing model 11
#   >11 0.895 (0.005)
# #13/20 processing model 12
